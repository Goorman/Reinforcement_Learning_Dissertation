# %%
import scipy
import scipy.misc
import numpy as np
import random
import pandas as pd
import gym
from tqdm import tqdm
from tqdm import tqdm_notebook
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import lasagne
import theano.tensor as T
import theano

# %%
# %load_ext autoreload
# %autoreload 2

# %%
class LunarLanding_wrapper():
    def __init__(self):
        self.state_size = (1, 8)
        self.game_title = "LunarLander-v2"
        self.actions = ["DO_NOTHING", "FIRE_LEFT", "FIRE_MAIN", "FIRE_RIGHT"]
        self.n_actions = len(self.actions)
        try:
            self.env = gym.make(self.game_title)
        except:
            print ("ERROR : Can't find " + self.game_title + " environment.")
            return None
        self.env.reset()
    
    def processState(self, state):
        return state.reshape(1, -1)
    
    def processAction(self, action):
        return action
    
    def make_reset(self):
        state = self.env.reset()
    
        return self.processState(state)
    
    def make_step(self, action, render = False):
        action = self.processAction(action)
    
        state, ret1, ret2, ret3 = self.env.step(action)
    
        if render:
            self.env.render()
    
        return self.processState(state), ret1, ret2, ret3

# %%
class CartPole_wrapper():
    def __init__(self):
        self.state_size = (1, 4)
        self.game_title = "CartPole-v0"
        self.actions = ["LEFT", "RIGHT"]
        self.n_actions = len(self.actions)
        try:
            self.env = gym.make(self.game_title)
        except:
            print ("ERROR : Can't find " + self.game_title + " environment.")
            return None
        self.env.reset()
    
    def processState(self, state):
        return state.reshape(1, -1)
    
    def processAction(self, action):
        return action
    
    def make_reset(self):
        state = self.env.reset()
    
        return self.processState(state)
    
    def make_step(self, action, render = False):
        action = self.processAction(action)
    
        state, ret1, ret2, ret3 = self.env.step(action)
    
        if render:
            self.env.render()
    
        return self.processState(state), ret1, ret2, ret3

# %%
class Acrobot_wrapper():
    def __init__(self):
        self.state_size = (1, 6)
        self.game_title = "Acrobot-v1"
        self.actions = ["LEFT", "NOTHING", "RIGHT"]
        self.n_actions = len(self.actions)
        try:
            self.env = gym.make(self.game_title)
        except:
            print ("ERROR : Can't find " + self.game_title + " environment.")
            return None
        self.env.reset()
    
    def processState(self, state):
        return state.reshape(1, -1)
    
    def processAction(self, action):
        return action
    
    def make_reset(self):
        state = self.env.reset()
    
        return self.processState(state)
    
    def make_step(self, action, render = False):
        action = self.processAction(action)
    
        state, ret1, ret2, ret3 = self.env.step(action)
    
        if render:
            self.env.render()
    
        return self.processState(state), ret1, ret2, ret3

# %%
class MountainCar_wrapper():
    def __init__(self):
        self.state_size = (1, 2)
        self.game_title = "MountainCar-v0"
        self.actions = ["LEFT", "RIGHT", "NOTHING"]
        self.n_actions = len(self.actions)
        try:
            self.env = gym.make(self.game_title)
        except:
            print ("ERROR : Can't find " + self.game_title + " environment.")
            return None
        self.env.reset()
    
    def processState(self, state):
        return state.reshape(1, -1)
    
    def processAction(self, action):
        return action
    
    def make_reset(self):
        state = self.env.reset()
    
        return self.processState(state)
    
    def make_step(self, action, render = False):
        action = self.processAction(action)
    
        state, ret1, ret2, ret3 = self.env.step(action)
    
        if render:
            self.env.render()
    
        return self.processState(state), ret1, ret2, ret3

# %%
class AVQ_nn():
    def __init__(self, channels_number = 4, image_shape = (1, 8), n_actions = 4, grad_clipping = 10, lr = 0.0001):
        self.input_var = T.tensor4('input')
        
        self.n_actions = n_actions
        self.build_network(channels_number, image_shape)
        self.build_AVQ(grad_clipping, lr)
        self.compile_network()
        
    def build_network(self, channels_number, image_shape):
        self.l1 = lasagne.layers.InputLayer(shape=(None, channels_number, image_shape[0], image_shape[1]), 
                                            input_var = self.input_var)
        self.l2 = lasagne.layers.DenseLayer(self.l1, 40, nonlinearity=lasagne.nonlinearities.leaky_rectify)
        self.l3 = lasagne.layers.DenseLayer(self.l2, 40, nonlinearity=lasagne.nonlinearities.leaky_rectify)
        self.outlayer = lasagne.layers.DenseLayer(self.l3, 50, nonlinearity=lasagne.nonlinearities.leaky_rectify)
    
    def build_AVQ(self, grad_clipping, lr):
        self.l_advantage = lasagne.layers.DenseLayer(self.outlayer, self.n_actions)
        self.l_value = lasagne.layers.DenseLayer(self.outlayer, 1)
        
        self.advantage, self.value = lasagne.layers.get_output([self.l_advantage, self.l_value])

        self.average_advantage = T.mean(self.advantage, keepdims = True, axis = 1)
        
#        self.Qout = self.advantage + self.value - self.average_advantage
        self.Qout = self.advantage + self.value * 0
        self.predict = T.argmax(self.Qout, axis = 1)
        
        self.targetQ = T.fvector('targetQ')
        self.actions = T.ivector('actions')
        self.actions_onehot = T.extra_ops.to_one_hot(self.actions, self.n_actions, dtype=np.float32)
        
        self.Q = T.sum(self.Qout * self.actions_onehot, axis = 1)
        
        self.td_error = T.sqr(self.targetQ - self.Q)
        self.loss = T.mean(self.td_error)
        
        params = self.get_all_params()
        self.all_grads = T.grad(self.loss, params)
        self.scaled_grads = lasagne.updates.total_norm_constraint(self.all_grads, grad_clipping)
        self.updates = lasagne.updates.adam(self.scaled_grads, params, learning_rate=lr)
        
    def compile_network(self):
        self.Qout_fn = theano.function([self.input_var], self.Qout)
        self.actionpred_fn = theano.function([self.input_var], self.predict)
        self.train_fn = theano.function([self.input_var, self.targetQ, self.actions], self.loss, updates = self.updates)
    
    def get_all_params(self):
        return lasagne.layers.get_all_params([self.l_advantage, self.l_value], trainable = True)
    
    def get_all_params_values(self):
        return lasagne.layers.get_all_param_values([self.l_advantage, self.l_value], trainable = True)
    
    def set_all_params_values(self, values):
        return lasagne.layers.set_all_param_values([self.l_advantage, self.l_value], values, trainable = True)

# %%
class experience_buffer():
    def __init__(self, buffer_size = 10000):
        self.buffer = []
        self.buffer_size = buffer_size
    
    def add(self, experience):
        if len(self.buffer) + len(experience) >= self.buffer_size:
            self.buffer[0:(len(experience)+len(self.buffer))-self.buffer_size] = []
        self.buffer.extend(experience)
            
    def sample(self, size):
        return np.reshape(np.array(random.sample(self.buffer,size)),[size,5])

# %%
class window_aggregator():
    def __init__(self, window_length, state_shape):
        self.state_shape = state_shape
        self.window_length = window_length
        
        assert len(self.state_shape) == 2
        assert self.window_length >= 1
        
        self.start_aggregator_shape = (window_length, state_shape[0], state_shape[1])
                                             
        self.aggregator = np.zeros(self.start_aggregator_shape)
        
    def reset(self):
        self.aggregator = np.zeros(self.start_aggregator_shape)
                                       
    def add_state(self, state):
        state = np.expand_dims(state, 0)
        self.aggregator = np.append(self.aggregator, state, axis = 0)
    
    def get_window(self):
        return self.aggregator[-self.window_length:,:,:]

# %%
class egreedy_agent():
    def __init__(self, n_actions, actionpred_fn, startE = 1, endE = 0.1, anneling_steps = 50000):
        self.startE = startE
        self.endE = endE
        self.anneling_steps = anneling_steps
        self.stepE = (self.startE - self.endE) / self.anneling_steps
        self.n_actions = n_actions
        self.actionpred_fn = actionpred_fn
    
    def choose_action(self, state, current_step):
        if current_step > self.anneling_steps:
            epsilon = self.endE
        else:
            epsilon = self.startE - self.stepE * current_step
        
        if np.random.rand(1) < epsilon:
            a = np.random.randint(0, self.n_actions)
        else:
            a = self.actionpred_fn(np.expand_dims(state, axis = 0))[0]
            
        return a

# %%
class boltzman_agent:
    def __init__(self, n_actions, Qout_fn, startT = 1000, endT = 0.1, anneling_steps = 50000):
        self.startT = startT
        self.endT = endT
        self.anneling_steps = anneling_steps
        self.logstep = (np.log(startT) - np.log(endT)) / anneling_steps
        self.n_actions = n_actions
        self.Qout_fn = Qout_fn
    
    def choose_action(self, state, current_step):
        scores = self.Qout_fn(np.expand_dims(state, axis = 0))[0]
        if current_step > self.anneling_steps:
            exponents = np.exp((scores - np.max(scores)) / self.endT)
        else:
            current_temp = self.startT / np.exp(self.logstep * current_step)
            exponents = np.exp((scores - np.max(scores)) / current_temp)
        probs = exponents / np.sum(exponents)
        return np.random.choice(self.n_actions, p = probs)

# %%
class DDQL():
    def __init__(self, lparams, env, agent = {"agent":"egreedy", "params":{}}):
        self.grad_clip = lparams["grad_clipping"]
        self.lr = lparams["learning_rate"]
        self.window_size = lparams["window_size"]
        self.batch_size = lparams["batch_size"]
        self.gamma = lparams["gamma"]
        self.MQN_updatefreq = lparams["MQN_updatefreq"]
        self.TQN_updatefreq = lparams["TQN_updatefreq"]
        self.TQN_updaterate = lparams["TQN_updaterate"]
        self.print_freq = lparams["print_freq"]
        self.pretrain_steps = lparams["pretrain_steps"]
        self.buffer_size = lparams["buffer_size"]
        self.pretrain_over = False
        
        self.env = env
        self.mainQN = AVQ_nn(self.window_size, self.env.state_size, self.env.n_actions, self.grad_clip, self.lr)
        self.targetQN = AVQ_nn(self.window_size, self.env.state_size, self.env.n_actions, self.grad_clip, self.lr)

        self.jList = []
        self.rList = []
        self.total_steps = 0
        
        self.window = window_aggregator(self.window_size, self.env.state_size)
        self.experience_storage = experience_buffer(self.buffer_size)
        self.agent = self.getAgent(agent["agent"], agent["params"])
            
    def getAgent(self, agent, agentparams):
        if agent == "egreedy":
            return egreedy_agent(self.env.n_actions, self.mainQN.actionpred_fn, **agentparams)
        elif agent == "boltzman":
            return boltzman_agent(self.env.n_actions, self.mainQN.Qout_fn, **agentparams)
        else:
            raise ValueError("Unknown agent")
            
    def updateTarget(self):
        self.targetQN.set_all_params_values(self.mainQN.get_all_params_values())
    
    def discount_rewards(self, r):
        return r
        
        discounted_r = np.zeros_like(r)
        running_add = 0
        for t in reversed(xrange(0, r.size)):
            running_add = running_add * self.gamma + r[t]
            discounted_r[t] = running_add
        return discounted_r

    def train(self, num_episodes, frame_limit, render = True):
        self.updateTarget()
        self.window.reset()
            
        for episode_num in tqdm_notebook(range(num_episodes), desc = "RL train"):
            episode_storage = experience_buffer()
            state = self.env.make_reset()
            self.window.add_state(state)
            window_state = self.window.get_window()
                
            for iteration in xrange(0, frame_limit):
                action = self.agent.choose_action(window_state, self.total_steps)
                new_state, reward, gameover, _ = self.env.make_step(action, render)
                self.window.add_state(new_state)
                new_window_state = self.window.get_window()
                episode_storage.add(np.reshape(np.array([window_state, action, reward, new_window_state, gameover]),[1,5]))
                    
                if self.pretrain_over:
                    self.total_steps += 1
                
                    if self.total_steps % (self.TQN_updatefreq) == 0:
                        self.updateTarget()
                
                    if self.total_steps % (self.MQN_updatefreq) == 0:
                        train_batch = self.experience_storage.sample(self.batch_size)
                        new_state_batch = np.stack(train_batch[:,3])
                        old_state_batch = np.stack(train_batch[:,0])
                        Q1 = self.mainQN.actionpred_fn(new_state_batch)   
                        Q2 = self.targetQN.Qout_fn(new_state_batch)
#                        Q2 = self.mainQN.Qout_fn(new_state_batch)
                        end_multiplier = -(train_batch[:,4] - 1)
                        doubleQ = Q2[range(self.batch_size),Q1]
                        targetQ = (train_batch[:,2] + (self.gamma * doubleQ * end_multiplier)).astype(np.float32)
                        action_vector = (train_batch[:,1]).astype(np.int32)
                        _ = self.mainQN.train_fn(old_state_batch, targetQ, action_vector)
                         
                else:
                    self.pretrain_steps -= 1;
                    if self.pretrain_steps <= 0:
                        self.pretrain_over = True
                        
                state = new_state
                window_state = new_window_state
            
                if gameover:
                    self.window.reset()
                    break
    
            episode_rewards = np.array(episode_storage.buffer)[:,2]
            total_reward = np.sum(episode_rewards)
            discount_rewards = self.discount_rewards(episode_rewards)
            buffer_array = np.array(episode_storage.buffer)
            buffer_array[:,2] = discount_rewards
            self.experience_storage.add(zip(buffer_array))
            self.jList.append(iteration)
            self.rList.append(total_reward)
            if len(self.rList) % self.print_freq == 0:
                tqdm.write(" ".join(["========= Episode", str(episode_num), "================================================"]))
                tqdm.write(" ".join(["Total steps:", str(self.total_steps)]))
                tqdm.write(" ".join(["Episode rewards, last 10:", str(self.rList[-10:])]))
                tqdm.write(" ".join(["Mean over last", str(self.print_freq), "episodes:", str(np.mean(self.rList[-self.print_freq:]))]))
                tqdm.write(" ".join(["Episode lengths, last 10:", str(self.jList[-10:])]))
                tqdm.write("===================================================================" + "=" * len(str(episode_num)))

# %%
def plot_rewards(ddqlmodel, meanwindow = 250):
    rlist = [ddqlmodel.rList[0]] * meanwindow + ddqlmodel.rList
    x = [np.mean(rlist[k:k+meanwindow]) for k in range(len(rlist) - meanwindow)]
    plt.plot(np.arange(len(x)), x)

# %%
ll_env = LunarLanding_wrapper()
#cp_env = CartPole_wrapper()
#mc_env = MountainCar_wrapper()
#ab_env = Acrobot_wrapper()
# Out:
# [2017-05-15 20:29:39,057] Making new env: LunarLander-v2

# %%
lparams = {"grad_clipping" : 50,
           "learning_rate" : 0.005,
           "window_size" : 1,
           "batch_size" : 8,
           "buffer_size" : 128,
           "gamma" : 0.98,
           "MQN_updatefreq" : 1,
           "TQN_updatefreq" : 16,
           "TQN_updaterate" : 0.01,
           "print_freq" : 125,
           "pretrain_steps" : 500,
           "render" : False}

# %%
egreedyagentinfo = {"agent" : "egreedy",
                    "params" : {"startE": 0.5,
                                "endE" : 0.1,
                                "anneling_steps":100000}}

# %%
boltzmanagentinfo = {"agent" : "boltzman",
                     "params" : {"startT": 10,
                                 "endT" : 1,
                                 "anneling_steps":10000}}

# %%
def produce_experiment(ddql, ddql_init_params, ddql_train_params, experiment_num = 5):
    ddql_list = [ddql(**ddql_init_params) for k in range(experiment_num)]
    
    for k in range(experiment_num):
        ddql_list[k].train(**ddql_train_params)
        
    return ddql_list

# %%
ddql_egreedy_params = {"lparams":lparams, "env":ll_env, "agent":egreedyagentinfo}
ddql_boltzman_params = {"lparams":lparams, "env":ll_env, "agent":boltzmanagentinfo}

ddql_train_params = {"num_episodes":1250, "frame_limit":200, "render":False}

# %%
res = produce_experiment(DDQL, ddql_egreedy_params, ddql_train_params, 10)
# Out:
# ========= Episode 124 ================================================
# Total steps: 14795
# Episode rewards, last 10: [-112.60973296388622, -107.80537417257291, -30.643671931696915, -43.001792464192377, -108.35797048422211, -149.0840618386726, -114.46437103432903, -146.1168263965389, 8.9949371792614912, -103.86342810789692]
# Mean over last 125 episodes: -212.386450655
# Episode lengths, last 10: [112, 90, 132, 147, 74, 106, 199, 74, 199, 153]
# ======================================================================
# ========= Episode 249 ================================================
# Total steps: 32133
# Episode rewards, last 10: [-151.9600516015492, -162.71198421015117, -243.57570888492967, -180.43227885807795, -232.46733649129141, 23.898581697720118, -343.61239189928619, -104.35585624851112, -247.54963294153941, -237.56682514410221]
# Mean over last 125 episodes: -127.194174407
# Episode lengths, last 10: [54, 65, 146, 173, 153, 199, 170, 150, 105, 199]
# ======================================================================
# ========= Episode 374 ================================================
# Total steps: 49151
# Episode rewards, last 10: [-9.6160554932487337, -311.83515776095021, -127.72504545557898, -71.457238409415851, -121.49842938275302, -145.44258072034128, -48.739775565984722, 28.555211590989792, -173.04187024728105, -257.42154981793965]
# Mean over last 125 episodes: -170.102641243
# Episode lengths, last 10: [199, 199, 134, 77, 120, 92, 185, 199, 72, 134]
# ======================================================================
# ========= Episode 499 ================================================
# Total steps: 60889
# Episode rewards, last 10: [-254.07588560313496, -99.949706398149445, -160.84384092668955, -189.29514355287239, -151.66260326355672, -194.70923141650402, -226.40552640787405, -253.43970337293248, -152.87887249727711, -183.0259673237413]
# Mean over last 125 episodes: -293.559550149
# Episode lengths, last 10: [70, 93, 58, 63, 60, 74, 69, 89, 58, 70]
# ======================================================================
# ========= Episode 624 ================================================
# Total steps: 70455
# Episode rewards, last 10: [-328.54125894972174, -157.21427007639761, -162.60021319408574, -174.18882689872549, -189.861586450038, -69.707501619331424, -179.48273555642379, -198.46535615033309, -222.36591057465321, -182.83657077804168]
# Mean over last 125 episodes: -192.600686021
# Episode lengths, last 10: [88, 52, 70, 96, 56, 93, 87, 61, 69, 77]
# ======================================================================
# ========= Episode 749 ================================================
# Total steps: 79807
# Episode rewards, last 10: [-233.14730423145866, -186.30531531587155, -216.61989067458515, -174.0945501848617, -169.9232977809815, -170.98246466678142, -211.16806714447938, -130.13268453092175, -195.84514369290201, -344.11106311302342]
# Mean over last 125 episodes: -191.234623856
# Episode lengths, last 10: [74, 63, 79, 71, 92, 55, 77, 94, 79, 100]
# ======================================================================
# ========= Episode 874 ================================================
# Total steps: 88854
# Episode rewards, last 10: [-162.55322080890917, -163.94083014266559, -217.11811582516918, -252.4585866181034, -164.30454460383265, -173.85370933945399, -265.8244605578285, -180.6160303047545, -274.31366296274433, -220.11049993596743]
# Mean over last 125 episodes: -176.658992825
# Episode lengths, last 10: [59, 90, 79, 94, 58, 72, 84, 82, 87, 73]
# ======================================================================
# ========= Episode 999 ================================================
# Total steps: 97869
# Episode rewards, last 10: [-248.43351549996328, -160.14675726233631, -153.81328461336722, -183.89640009687486, -167.33095064037224, -175.12699758929443, -175.33991866768537, -179.48639283307057, -234.37879977640137, -14.098870816769434]
# Mean over last 125 episodes: -183.39334624
# Episode lengths, last 10: [82, 84, 78, 68, 59, 75, 64, 60, 73, 85]
# ======================================================================
# ========= Episode 1124 ================================================
# Total steps: 107201
# Episode rewards, last 10: [-134.22387833729891, -340.69993069378563, -179.41566418352761, -170.85519028024788, -243.08862815227329, -199.57862868305315, -207.27872604519143, -211.59771235230971, -209.57931928689084, -307.06918418947259]
# Mean over last 125 episodes: -185.53415367
# Episode lengths, last 10: [91, 88, 92, 90, 93, 95, 82, 75, 71, 84]
# =======================================================================
# ========= Episode 1249 ================================================
# Total steps: 116288
# Episode rewards, last 10: [-204.73738558245316, -221.46650695804561, -182.29310920979401, -196.80371511368273, -203.40446863045884, -193.52958813930189, -186.90666041326665, -193.35925070619851, -253.51229151255527, -210.93489122818343]
# Mean over last 125 episodes: -176.241236938
# Episode lengths, last 10: [74, 77, 68, 85, 83, 68, 63, 58, 79, 67]
# =======================================================================
#
# ========= Episode 124 ================================================
# Total steps: 9229
# Episode rewards, last 10: [-134.83728114314005, -133.33355873727544, -240.05996069480241, -261.50826324396706, -341.62849969697447, -144.57994209233698, -141.97120800830601, -226.79217821173413, -163.27351475709824, -251.46186100536215]
# Mean over last 125 episodes: -217.294894818
# Episode lengths, last 10: [57, 57, 106, 93, 69, 68, 52, 84, 77, 107]
# ======================================================================
# ========= Episode 249 ================================================
# Total steps: 19095
# Episode rewards, last 10: [-316.86020859301391, -123.18863194137924, -187.15040785865745, -153.88816824435435, -160.88225302813404, -180.08789803526093, -169.1360662234155, -158.07109275328969, -327.83353412186261, -161.44795076144814]
# Mean over last 125 episodes: -194.342183343
# Episode lengths, last 10: [103, 96, 85, 57, 66, 106, 97, 73, 92, 68]
# ======================================================================
# ========= Episode 374 ================================================
# Total steps: 28881
# Episode rewards, last 10: [-244.82460397878867, -207.63709466526595, -242.44243528453035, -195.4007030645443, -161.68094423975211, -239.04444622516712, -171.61095690501321, -154.60991739069203, -192.64158396216632, -165.62767048939946]
# Mean over last 125 episodes: -189.730299354
# Episode lengths, last 10: [83, 74, 73, 78, 68, 61, 76, 69, 74, 88]
# ======================================================================
# ========= Episode 499 ================================================
# Total steps: 38331
# Episode rewards, last 10: [-210.31816383343309, -167.40816791674604, -160.38320955217802, -120.12498763682831, -157.37853345012104, -193.70856602276081, -168.24881019131595, -261.30706367421237, -146.13487381323569, -183.02675586719022]
# Mean over last 125 episodes: -183.496314984
# Episode lengths, last 10: [87, 71, 71, 55, 80, 80, 64, 74, 96, 81]
# ======================================================================
# ========= Episode 624 ================================================
# Total steps: 48024
# Episode rewards, last 10: [-170.68861527459717, -151.71082397571607, -154.00398449721783, -161.74274361335026, -161.74948068441137, -228.57254834477072, -211.35454505779134, -158.46414547621066, -201.78706779719923, -168.61698389834555]
# Mean over last 125 episodes: -178.030591966
# Episode lengths, last 10: [64, 71, 75, 90, 68, 87, 67, 58, 62, 85]
# ======================================================================
# ========= Episode 749 ================================================
# Total steps: 57782
# Episode rewards, last 10: [-182.80262655438602, -197.29525539698415, -150.73824926201473, -151.823629380027, -223.61027903887697, -133.19931091764721, -173.7907845616578, -172.26201348077143, -270.07172076860638, -285.14846237526751]
# Mean over last 125 episodes: -187.484063246
# Episode lengths, last 10: [59, 68, 79, 65, 60, 71, 97, 53, 79, 80]
# ======================================================================
# ========= Episode 874 ================================================
# Total steps: 67099
# Episode rewards, last 10: [-182.52247243221973, -217.10248522702284, -161.75802988539249, -172.05590404248929, -164.31147037169478, -265.52248411079285, -37.396524803190246, -147.80297996395905, -154.72273576050196, -227.8735845490348]
# Mean over last 125 episodes: -184.556814362
# Episode lengths, last 10: [59, 56, 92, 53, 89, 88, 82, 61, 93, 90]
# ======================================================================
# ========= Episode 999 ================================================
# Total steps: 76291
# Episode rewards, last 10: [-144.83977531301622, -196.14634498575816, -166.81533550170445, -192.95895565974442, -124.31432249834187, -211.66367657254739, -141.34505855627253, -195.41246977264035, -186.41787460492509, -205.23403944725678]
# Mean over last 125 episodes: -183.572421179
# Episode lengths, last 10: [52, 80, 59, 68, 52, 56, 58, 68, 82, 67]
# ======================================================================
# ========= Episode 1124 ================================================
# Total steps: 85358
# Episode rewards, last 10: [-144.49131801420606, -184.57665092061893, -191.88186014459612, -277.89730664777176, -176.94930179676098, -247.69195099966521, -142.64635043506127, -163.96750879153032, -191.06006035516276, -183.03038670537069]
# Mean over last 125 episodes: -187.195741237
# Episode lengths, last 10: [54, 54, 63, 79, 76, 88, 59, 71, 72, 74]
# =======================================================================
# ========= Episode 1249 ================================================
# Total steps: 94248
# Episode rewards, last 10: [-154.86748058300265, -173.7713071832199, -122.85130053008174, -129.92432015258112, -157.83535175849067, -165.99729234760912, -166.09424486796914, -173.00540556436187, -155.99668437728187, -159.51227501284842]
# Mean over last 125 episodes: -179.335586706
# Episode lengths, last 10: [62, 84, 57, 53, 63, 65, 67, 76, 61, 77]
# =======================================================================
#
# ========= Episode 124 ================================================
# Total steps: 9642
# Episode rewards, last 10: [-165.16894352022092, -325.65760058730461, -239.38151898646524, -168.35085714767251, -229.54841756536811, -135.06206737497052, -190.03767597943579, -199.58310069751053, -218.11501168346075, -150.6938176954983]
# Mean over last 125 episodes: -216.546788191
# Episode lengths, last 10: [89, 101, 75, 77, 69, 83, 57, 61, 71, 59]
# ======================================================================
# ========= Episode 249 ================================================
# Total steps: 19357
# Episode rewards, last 10: [-215.539215451654, -171.16896773349103, -150.91048472987296, -138.51229328767869, -191.38603583377096, -200.88601112191469, -191.07460679517337, -358.16505271232569, -147.07909600507674, -194.01755620086954]
# Mean over last 125 episodes: -194.888758965
# Episode lengths, last 10: [74, 63, 67, 82, 102, 57, 83, 104, 70, 68]
# ======================================================================
# ========= Episode 374 ================================================
# Total steps: 29219
# Episode rewards, last 10: [-211.03990073170047, -204.49754719110064, -136.61397041344202, -183.20656034695128, -203.88620957320217, -76.296289654629703, 20.328902181958256, -22.546956772848944, -322.56921093957544, -132.42798561585252]
# Mean over last 125 episodes: -196.254073391
# Episode lengths, last 10: [96, 92, 59, 68, 85, 91, 112, 104, 95, 90]
# ======================================================================
# ========= Episode 499 ================================================
# Total steps: 38629
# Episode rewards, last 10: [-147.29588436499907, -252.61730710500461, -137.45503609288528, -135.32650628769673, -189.60200000258317, -139.02589835258019, -209.04626207125077, -195.57229505718834, -148.39219474987902, -207.29154702241269]
# Mean over last 125 episodes: -190.05550052
# Episode lengths, last 10: [59, 93, 67, 58, 63, 84, 62, 62, 61, 57]
# ======================================================================
# ========= Episode 624 ================================================
# Total steps: 48059
# Episode rewards, last 10: [-148.13351824163439, -249.5843068906465, -154.26273372017604, -171.57387193264208, -197.43468246739556, -354.35181399083979, -189.67438019115872, -214.64982919661537, -179.96118306432501, -126.0771799568239]
# Mean over last 125 episodes: -178.97480017
# Episode lengths, last 10: [59, 92, 87, 76, 81, 95, 96, 60, 55, 53]
# ======================================================================
# ========= Episode 749 ================================================
# Total steps: 57316
# Episode rewards, last 10: [-187.44794926033222, -194.94131625921568, -182.32850433660226, -171.48406720794716, -183.39264106792803, -184.89992221615532, -217.68923480645697, -182.31024321411996, -150.71138571246644, -197.33360401963702]
# Mean over last 125 episodes: -175.344453095
# Episode lengths, last 10: [58, 71, 53, 65, 67, 55, 96, 82, 65, 70]
# ======================================================================
# ========= Episode 874 ================================================
# Total steps: 66697
# Episode rewards, last 10: [-32.39523771709905, -231.42334632612753, -219.7772857727239, -218.58200815515266, -161.71414901328399, -96.038221460102548, -214.19063980439438, -134.78116332162784, -158.21987599926018, -169.77970762707895]
# Mean over last 125 episodes: -185.037474551
# Episode lengths, last 10: [70, 87, 104, 71, 81, 87, 97, 58, 57, 74]
# ======================================================================
# ========= Episode 999 ================================================
# Total steps: 75870
# Episode rewards, last 10: [-274.42099311097519, -187.87729018333431, -152.82880397415428, -177.44693695920756, -152.05930448457772, -161.34795769650194, -235.90143801044968, -162.02458864500784, -160.24452928602443, -184.9047299781225]
# Mean over last 125 episodes: -179.584626939
# Episode lengths, last 10: [90, 60, 67, 74, 83, 61, 78, 59, 62, 74]
# ======================================================================
# ========= Episode 1124 ================================================
# Total steps: 84916
# Episode rewards, last 10: [-268.67657491989314, -35.069082169231251, -202.48639121021091, -160.55137725331068, -247.27094511087427, -166.60048135032105, -216.91094173705409, -177.66135511606959, -29.593596272721626, -167.46446394766463]
# Mean over last 125 episodes: -182.117561031
# Episode lengths, last 10: [73, 72, 82, 55, 65, 74, 65, 56, 76, 63]
# =======================================================================
# ========= Episode 1249 ================================================
# Total steps: 93961
# Episode rewards, last 10: [-254.39526254152929, -137.27133729843916, -186.75809582220916, -180.63022788132173, -164.85063388103777, -224.1661865460415, -238.88127298911832, -146.79929325724478, -145.18200467971718, -298.38745054497559]
# Mean over last 125 episodes: -188.00702825
# Episode lengths, last 10: [81, 59, 72, 55, 91, 73, 92, 51, 62, 81]
# =======================================================================
#
# ========= Episode 124 ================================================
# Total steps: 9776
# Episode rewards, last 10: [-197.38767744596214, -171.73975122032576, -125.93303328337848, -142.72114861429532, -194.73946583852023, -271.71954505389851, -196.57736318946897, -146.80027480647067, -170.77880766540545, -35.760901441661659]
# Mean over last 125 episodes: -194.640489027
# Episode lengths, last 10: [82, 73, 70, 108, 72, 65, 99, 58, 57, 59]
# ======================================================================
# ========= Episode 249 ================================================
# Total steps: 19498
# Episode rewards, last 10: [-146.33930191712525, -218.26798414428916, -192.53462902573332, -160.70573913578585, -255.26457787048867, -195.83138028427044, -177.91484631551913, -138.23623491701443, -183.59837764024388, -161.7757008344436]
# Mean over last 125 episodes: -195.711535457
# Episode lengths, last 10: [98, 88, 75, 89, 61, 60, 66, 55, 75, 74]
# ======================================================================
# ========= Episode 374 ================================================
# Total steps: 29363
# Episode rewards, last 10: [-327.51750664134431, -77.782326841134136, -173.84770224259421, -175.45829317408896, -171.19528401031263, -367.80272779108367, -164.1957813726687, -162.56062422803527, -205.06055127995381, -192.98545072299126]
# Mean over last 125 episodes: -191.258224243
# Episode lengths, last 10: [93, 98, 83, 78, 100, 80, 81, 67, 86, 73]
# ======================================================================
# ========= Episode 499 ================================================
# Total steps: 38893
# Episode rewards, last 10: [-145.15388884208591, -124.3470268299647, -130.72822701684237, -140.92397358031263, -234.26179201124359, -177.79712566789476, -160.79495630704525, -179.09052704281805, -141.94657081742568, -180.7481042452128]
# Mean over last 125 episodes: -193.141993277
# Episode lengths, last 10: [54, 97, 55, 83, 71, 59, 82, 63, 65, 54]
# ======================================================================
# ========= Episode 624 ================================================
# Total steps: 48471
# Episode rewards, last 10: [-239.38867428476343, -176.42121158354405, -178.91833890901313, -184.07994115568414, -158.13258394339778, -280.14414534789643, -181.61914145532066, -174.67312040407967, -299.97672847115587, -201.4862283910098]
# Mean over last 125 episodes: -191.119470474
# Episode lengths, last 10: [90, 59, 87, 77, 77, 85, 60, 56, 86, 57]
# ======================================================================
# ========= Episode 749 ================================================
# Total steps: 57619
# Episode rewards, last 10: [-180.37215594431811, -153.09823159107037, -169.61732777261511, -188.78085280743051, -246.76129232522106, -166.76176002908545, -180.55495251637933, -149.38827339408112, -151.54610280885069, -271.0503020442693]
# Mean over last 125 episodes: -186.228933105
# Episode lengths, last 10: [57, 57, 51, 64, 80, 52, 52, 57, 99, 84]
# ======================================================================
# ========= Episode 874 ================================================
# Total steps: 67054
# Episode rewards, last 10: [-201.98221677705044, -210.65587893873155, -158.31734431211481, -154.56622692590332, -127.62086663782509, -180.1278535887314, -197.58673278050239, -220.999722164567, -193.05498603024967, -259.69554914512275]
# Mean over last 125 episodes: -183.796365626
# Episode lengths, last 10: [73, 85, 102, 54, 54, 88, 64, 74, 56, 86]
# ======================================================================
# ========= Episode 999 ================================================
# Total steps: 76266
# Episode rewards, last 10: [-180.7080499370436, -154.66439793140177, -335.02892063682134, -189.46468103172401, -189.31583722117878, -166.48232849271088, -185.15851325473602, -194.5381572255107, -221.72254511076946, -80.986279291031352]
# Mean over last 125 episodes: -183.808932648
# Episode lengths, last 10: [73, 76, 70, 75, 76, 86, 90, 71, 69, 77]
# ======================================================================
# ========= Episode 1124 ================================================
# Total steps: 85360
# Episode rewards, last 10: [-205.44846736147383, -211.03354739364437, -148.60569476123942, -130.99332460166806, -172.55147543976463, -193.97058499270204, -73.06927642288116, -204.8063879013738, -187.71727430070143, -126.34800617264244]
# Mean over last 125 episodes: -188.027339951
# Episode lengths, last 10: [61, 93, 55, 54, 57, 76, 90, 61, 81, 55]
# =======================================================================
# ========= Episode 1249 ================================================
# Total steps: 94390
# Episode rewards, last 10: [-160.39355845723958, -537.222804784343, -177.63896667958343, -178.7022103794763, -204.6045974774309, -219.38932755351584, -176.42096864318756, -200.93871306559356, -35.549029394673354, -202.24954369383815]
# Mean over last 125 episodes: -186.31507549
# Episode lengths, last 10: [61, 106, 80, 56, 77, 68, 63, 73, 78, 69]
# =======================================================================
#
# ========= Episode 124 ================================================
# Total steps: 9566
# Episode rewards, last 10: [-168.7964297445717, -135.87979870757457, -161.25694278209198, -176.85391654091583, -155.15364557482872, -190.52866461766456, -221.13938331762554, -143.86956816434065, -154.63038549314911, -374.43371896219708]
# Mean over last 125 episodes: -208.405693307
# Episode lengths, last 10: [101, 62, 111, 86, 59, 78, 69, 95, 85, 95]
# ======================================================================
# ========= Episode 249 ================================================
# Total steps: 19406
# Episode rewards, last 10: [-150.01605572353898, -236.03318296148558, -80.916795444630878, -157.78716347924211, -153.72630143960703, -179.65762502861315, -352.90001789944404, -237.54781023120569, -144.95507685531706, -243.61260518272508]
# Mean over last 125 episodes: -202.031613363
# Episode lengths, last 10: [52, 61, 107, 83, 62, 93, 92, 93, 61, 82]
# ======================================================================
# ========= Episode 374 ================================================
# Total steps: 28967
# Episode rewards, last 10: [-179.97031113466403, -189.99424207555603, -198.03854255923761, -164.3018690561193, -167.29068898862991, -202.93829259380163, -166.01319143392445, -209.31293433117673, -167.93458432275912, -179.67092472157287]
# Mean over last 125 episodes: -182.150937519
# Episode lengths, last 10: [69, 82, 64, 73, 96, 72, 61, 90, 98, 56]
# ======================================================================
# ========= Episode 499 ================================================
# Total steps: 38528
# Episode rewards, last 10: [-193.75645117066654, -151.51649652889415, -184.7156753144767, -146.38209321605783, -109.2381450732979, -203.78135351159167, -311.69573775415779, -148.95713886350194, -114.09934936814143, -69.884681578948786]
# Mean over last 125 episodes: -173.293356467
# Episode lengths, last 10: [62, 85, 89, 55, 58, 60, 72, 62, 58, 64]
# ======================================================================
# ========= Episode 624 ================================================
# Total steps: 47967
# Episode rewards, last 10: [-152.66529945639542, -152.59261228250347, -185.99513108406398, -317.99771476360223, -188.02135061754393, -133.26762383808625, -130.80855672744138, -172.38309766342601, -175.99134635205661, -169.70282196478377]
# Mean over last 125 episodes: -180.528878183
# Episode lengths, last 10: [85, 55, 92, 99, 86, 61, 105, 57, 102, 59]
# ======================================================================
# ========= Episode 749 ================================================
# Total steps: 57327
# Episode rewards, last 10: [-254.70576969763314, -219.09790745305759, -148.11831342199105, -212.63059909684785, -170.59196650868918, -183.295788313066, -201.89994922554598, -184.38599779795408, -132.55896936334491, -158.15851394421895]
# Mean over last 125 episodes: -185.780529451
# Episode lengths, last 10: [82, 65, 58, 85, 60, 79, 57, 67, 85, 61]
# ======================================================================
# ========= Episode 874 ================================================
# Total steps: 66610
# Episode rewards, last 10: [-274.58936278210876, -136.14752146582586, -194.57268817668086, -147.95618327823348, -179.87031921520844, -156.58315566743781, -168.79764382386173, -155.97163355161817, -63.508759230477366, -207.63526737718763]
# Mean over last 125 episodes: -183.114463321
# Episode lengths, last 10: [81, 87, 60, 86, 62, 66, 53, 58, 78, 95]
# ======================================================================
# ========= Episode 999 ================================================
# Total steps: 75763
# Episode rewards, last 10: [-141.33637055814251, -211.0648204165411, -234.82078529915634, -231.27948120516459, -171.27119261845044, -159.38350325445663, -184.34819051883503, -263.25335535640579, -190.71872637527707, -142.15588042079176]
# Mean over last 125 episodes: -193.961788459
# Episode lengths, last 10: [59, 69, 71, 80, 83, 91, 82, 98, 69, 58]
# ======================================================================
# ========= Episode 1124 ================================================
# Total steps: 84691
# Episode rewards, last 10: [-176.96681371475296, -163.13434486650431, -140.8122881474757, -216.46285725369111, -162.11292875892732, -26.869713462885812, -201.71309293570152, -181.5033099036591, -159.94159722372581, -334.70539362709343]
# Mean over last 125 episodes: -180.463193332
# Episode lengths, last 10: [53, 51, 51, 81, 53, 65, 77, 77, 53, 107]
# =======================================================================
# ========= Episode 1249 ================================================
# Total steps: 93528
# Episode rewards, last 10: [-179.52076515098065, -228.79672389696123, -158.11245512052244, -186.65347689536696, -136.74297847247152, -158.19058887530031, -241.72133574429915, -159.76656051238947, -182.4907809003619, -173.01684160243107]
# Mean over last 125 episodes: -182.374968706
# Episode lengths, last 10: [68, 81, 66, 89, 51, 63, 85, 52, 67, 56]
# =======================================================================
#
# ========= Episode 124 ================================================
# Total steps: 11882
# Episode rewards, last 10: [-47.401369630576397, -233.3784063860586, -238.50421502793526, -200.7251557167545, -199.15670697459677, -214.82388109148332, -160.10934302073338, -252.64097903428296, -213.89944214051792, -132.39162755612057]
# Mean over last 125 episodes: -219.645547699
# Episode lengths, last 10: [55, 74, 78, 71, 85, 101, 63, 92, 72, 99]
# ======================================================================
# ========= Episode 249 ================================================
# Total steps: 25290
# Episode rewards, last 10: [23.390377944598427, -574.65955961505642, -609.94611655972767, -700.72729893251085, -15.152919131690757, -237.52040404528165, -368.18798905244699, -315.91363610785061, -203.65097249528469, -264.95684945800912]
# Mean over last 125 episodes: -213.730223037
# Episode lengths, last 10: [199, 197, 83, 114, 199, 105, 128, 124, 103, 101]
# ======================================================================
# ========= Episode 374 ================================================
# Total steps: 40001
# Episode rewards, last 10: [-213.04789746094008, -147.93261683897327, -235.11393065245227, -157.91160099992248, -216.70772852965331, -255.66377214024953, -50.098194893996101, -32.131667638078483, -159.51879859782389, -11.20955448892591]
# Mean over last 125 episodes: -179.036201669
# Episode lengths, last 10: [63, 182, 105, 94, 85, 110, 149, 199, 102, 199]
# ======================================================================
# ========= Episode 499 ================================================
# Total steps: 53008
# Episode rewards, last 10: [-145.12578862016676, -140.77251743367631, -310.06897990255584, -168.0594550507804, -192.20217280278783, -179.28588260193052, -136.4435959491812, -124.33355299026591, -222.0045834633878, -85.869223918348254]
# Mean over last 125 episodes: -182.751670863
# Episode lengths, last 10: [62, 86, 93, 68, 79, 61, 69, 57, 79, 87]
# ======================================================================
# ========= Episode 624 ================================================
# Total steps: 63914
# Episode rewards, last 10: [-131.48376131336218, -133.11845394631132, -196.84490717141949, -89.529130925435155, -145.9685333658517, -96.947100094733671, -111.40166475821482, -134.573905520457, -150.42714629789901, -185.86264376693669]
# Mean over last 125 episodes: -172.302261151
# Episode lengths, last 10: [56, 100, 74, 96, 87, 51, 84, 102, 87, 72]
# ======================================================================
# ========= Episode 749 ================================================
# Total steps: 75423
# Episode rewards, last 10: [90.354251081606137, -178.01308106828535, -182.32452014030775, -111.15185709261506, -202.15497455531752, -219.21263488126306, -231.83897560950624, -234.43063977491497, -83.619982470529521, -167.57875772468043]
# Mean over last 125 episodes: -168.982260858
# Episode lengths, last 10: [199, 90, 60, 130, 74, 61, 98, 62, 75, 111]
# ======================================================================
# ========= Episode 874 ================================================
# Total steps: 90504
# Episode rewards, last 10: [-172.29230708802311, -149.30008180211939, -105.89623452296038, -221.62658208181591, -191.90228360351702, -1.3432495436191163, -359.07893219480616, -159.20062256424501, -221.46491368970729, -403.07659291584429]
# Mean over last 125 episodes: -174.291963548
# Episode lengths, last 10: [160, 58, 199, 109, 102, 199, 199, 178, 119, 127]
# ======================================================================
# ========= Episode 999 ================================================
# Total steps: 108822
# Episode rewards, last 10: [-9.0395545736424445, 16.166627147817966, -64.681058896371511, -193.36400444173722, -276.22380106624053, -202.59347586355193, -50.866538357136122, -71.053105216715991, -178.93479973946614, -142.55064234958377]
# Mean over last 125 episodes: -156.929719382
# Episode lengths, last 10: [199, 199, 199, 75, 190, 102, 199, 199, 115, 199]
# ======================================================================
# ========= Episode 1124 ================================================
# Total steps: 129125
# Episode rewards, last 10: [-126.6455211452943, -127.6784200569806, -103.61875746069428, -248.84168247785291, -238.35672558003097, -111.15697985058276, -80.03652633195901, 16.332124627884301, -108.10924926389394, -347.84903909881302]
# Mean over last 125 episodes: -139.949874141
# Episode lengths, last 10: [81, 199, 199, 64, 157, 199, 199, 199, 199, 155]
# =======================================================================
# ========= Episode 1249 ================================================
# Total steps: 149698
# Episode rewards, last 10: [-243.11260124434111, -136.15104002295888, -18.570409887552639, -164.48051746919788, -43.983151383119434, 55.17469220755882, -160.23534954103303, -165.73871194969615, -180.79211856253812, -189.01616605018506]
# Mean over last 125 episodes: -103.961123548
# Episode lengths, last 10: [105, 199, 199, 199, 90, 199, 135, 63, 92, 91]
# =======================================================================
#
# ========= Episode 124 ================================================
# Total steps: 9380
# Episode rewards, last 10: [-139.19981917158537, -207.170533081896, -193.20586821682747, -439.63288961597857, -168.38129091522865, -136.64945395307225, -252.83997958756078, -183.56853393159196, -234.00932226968158, -165.03061143378173]
# Mean over last 125 episodes: -201.202502733
# Episode lengths, last 10: [64, 87, 64, 102, 68, 63, 71, 72, 69, 81]
# ======================================================================
# ========= Episode 249 ================================================
# Total steps: 19202
# Episode rewards, last 10: [-332.14928411093274, -181.40710422092957, -135.87086185530092, -178.16536562295124, -182.18101167879001, -172.13931449172196, -160.70481883096329, -202.3004391526415, -186.06021480081858, -118.98148093627312]
# Mean over last 125 episodes: -191.637950541
# Episode lengths, last 10: [93, 89, 99, 70, 67, 64, 71, 83, 90, 62]
# ======================================================================
# ========= Episode 374 ================================================
# Total steps: 29104
# Episode rewards, last 10: [-159.39650253583306, -131.74507355834277, -140.6923931251772, -221.44388175151062, -164.16314477134307, -169.39058174108573, -185.10815435825765, -60.269227201005862, -128.75813128344893, -208.09495781997978]
# Mean over last 125 episodes: -184.287276347
# Episode lengths, last 10: [59, 97, 57, 61, 87, 83, 66, 65, 54, 89]
# ======================================================================
# ========= Episode 499 ================================================
# Total steps: 38660
# Episode rewards, last 10: [-237.99306612988278, -156.7479485046679, -159.95365430353576, -118.81867746247286, -265.80802222397841, -175.36623658715396, -384.71913617900344, -179.66206688059509, -169.08110981374796, -249.74401814255012]
# Mean over last 125 episodes: -189.891606716
# Episode lengths, last 10: [96, 76, 56, 55, 76, 82, 107, 66, 76, 75]
# ======================================================================
# ========= Episode 624 ================================================
# Total steps: 48254
# Episode rewards, last 10: [-184.34187942748488, -164.36141362347564, -173.67862713649356, -228.10193736544588, -163.99774065059654, -361.99408197162586, -172.17525413546687, -182.72832109167194, -182.63845958681151, -149.11866902666492]
# Mean over last 125 episodes: -191.898174118
# Episode lengths, last 10: [73, 68, 70, 88, 86, 96, 67, 90, 67, 62]
# ======================================================================
# ========= Episode 749 ================================================
# Total steps: 57553
# Episode rewards, last 10: [-148.39781634502813, -152.55011268426179, -178.58985686910802, -167.55358481005152, -192.77289709413449, -258.60551629503448, -188.64059369060698, -173.4153819908056, -156.89913340886531, -194.64948153669633]
# Mean over last 125 episodes: -185.197466666
# Episode lengths, last 10: [53, 54, 54, 84, 73, 78, 79, 69, 56, 65]
# ======================================================================
# ========= Episode 874 ================================================
# Total steps: 66796
# Episode rewards, last 10: [-154.4144701194603, -243.99313531326288, -144.70640668878269, -199.02237968892166, -208.49455450317197, -146.45341121388697, -195.95894733713533, -208.87000283435356, -165.09447352798301, -157.50271279828678]
# Mean over last 125 episodes: -183.17280094
# Episode lengths, last 10: [56, 71, 75, 75, 89, 52, 71, 57, 74, 66]
# ======================================================================
# ========= Episode 999 ================================================
# Total steps: 75813
# Episode rewards, last 10: [-159.35781295821079, -136.03090595383608, -150.93486424723346, -218.70093714555057, -137.49362420295691, -217.49563560392963, -195.47937969898263, -172.92245161256758, -171.93203594946308, -148.70828974216863]
# Mean over last 125 episodes: -175.010712373
# Episode lengths, last 10: [59, 91, 57, 72, 55, 73, 75, 87, 56, 65]
# ======================================================================
# ========= Episode 1124 ================================================
# Total steps: 84825
# Episode rewards, last 10: [-261.85552107855358, -232.46752644631403, -211.46007495401548, -162.50707012470116, -206.03502844773647, -122.88801535867591, -146.42689207494232, -197.31679592050688, -177.23274027165263, -203.52629757488478]
# Mean over last 125 episodes: -186.691186361
# Episode lengths, last 10: [87, 83, 64, 70, 69, 52, 52, 65, 62, 70]
# =======================================================================
# ========= Episode 1249 ================================================
# Total steps: 93810
# Episode rewards, last 10: [-187.61353251908443, -75.252960016767261, -190.66265990576159, -191.88561621236249, -158.66930663006758, -460.10317830443671, -27.632337032447452, -194.04412519652772, -164.21333118212934, -244.54096716237433]
# Mean over last 125 episodes: -175.768522956
# Episode lengths, last 10: [67, 69, 67, 85, 59, 106, 68, 84, 55, 74]
# =======================================================================
#
# ========= Episode 124 ================================================
# Total steps: 9916
# Episode rewards, last 10: [-185.15093807399296, -208.04043334905751, -122.7132723592033, -159.03876030147862, -170.19761674277231, -162.84360320036345, -151.70094955701063, -396.37612016972497, -183.75705660903051, -223.40815879206042]
# Mean over last 125 episodes: -202.238191441
# Episode lengths, last 10: [70, 66, 60, 73, 82, 91, 96, 96, 63, 89]
# ======================================================================
# ========= Episode 249 ================================================
# Total steps: 19723
# Episode rewards, last 10: [-174.31182353103281, -189.939191704601, -246.35368716819795, -291.76541584622203, -160.37783918877756, -366.00355593771309, -164.08017432735497, -103.06138215628606, -177.25109588537862, -208.13766788193107]
# Mean over last 125 episodes: -187.481767145
# Episode lengths, last 10: [86, 69, 97, 88, 69, 106, 61, 70, 75, 98]
# ======================================================================
# ========= Episode 374 ================================================
# Total steps: 29521
# Episode rewards, last 10: [-145.41206507588444, -345.88093954867963, -193.32580692700895, -285.30219636623167, -140.93188399674551, -152.85686119704962, -148.19270166955914, -163.56078913440899, -186.01886789528439, -43.998846648505413]
# Mean over last 125 episodes: -184.432111121
# Episode lengths, last 10: [91, 104, 70, 82, 95, 79, 61, 78, 95, 90]
# ======================================================================
# ========= Episode 499 ================================================
# Total steps: 38898
# Episode rewards, last 10: [-176.99001881260219, -186.43614074369788, -209.24747185043134, -179.20499788176625, -186.70237995887965, -187.22479956585011, -218.50215827982606, -161.86330478586805, -199.33340326434387, -286.03178929699197]
# Mean over last 125 episodes: -187.250700978
# Episode lengths, last 10: [83, 83, 86, 85, 69, 103, 62, 71, 60, 85]
# ======================================================================
# ========= Episode 624 ================================================
# Total steps: 48653
# Episode rewards, last 10: [-177.35281498763788, -229.88149741043185, -172.2466850139254, -175.07502370850207, -184.11487031973877, -143.85004979026741, -256.54014095069988, -146.390927847505, -185.24071862367668, -289.63491877144708]
# Mean over last 125 episodes: -182.392013179
# Episode lengths, last 10: [80, 91, 65, 81, 70, 81, 83, 59, 69, 94]
# ======================================================================
# ========= Episode 749 ================================================
# Total steps: 58300
# Episode rewards, last 10: [-160.11668134730786, -250.56461294275996, -104.92423589051603, -164.14245289450787, -161.68166449813057, -189.19821492216096, -71.970380075621904, 5.4175508966906563, -184.03057776911209, -168.10646478343921]
# Mean over last 125 episodes: -180.478395335
# Episode lengths, last 10: [63, 72, 59, 90, 82, 74, 100, 118, 93, 75]
# ======================================================================
# ========= Episode 874 ================================================
# Total steps: 67228
# Episode rewards, last 10: [-167.94623156721678, -181.37168996492025, -255.56923408552581, -184.66632282351384, -190.20944150006298, -122.54345117454172, -147.22832810558569, -137.7429767888774, -212.19249973673473, -223.91153188294459]
# Mean over last 125 episodes: -181.697303848
# Episode lengths, last 10: [61, 75, 81, 54, 70, 52, 101, 84, 82, 81]
# ======================================================================
# ========= Episode 999 ================================================
# Total steps: 76684
# Episode rewards, last 10: [-149.20415080968337, -197.74912387761444, -187.48968354026445, -264.44079627603912, -261.7126430341022, -239.44177264537177, -166.20805678400652, -276.13221682798985, -276.23336511287914, -200.68214066152586]
# Mean over last 125 episodes: -189.852770162
# Episode lengths, last 10: [77, 57, 59, 88, 88, 65, 81, 93, 91, 72]
# ======================================================================
# ========= Episode 1124 ================================================
# Total steps: 85781
# Episode rewards, last 10: [-214.54079457056565, -170.80526876227316, -147.13097683108219, -182.99322821278309, -199.65871243489812, -151.65249206319828, -176.93781941307265, -183.339296074407, -178.6936152499033, -151.04126367791059]
# Mean over last 125 episodes: -182.600616985
# Episode lengths, last 10: [57, 89, 52, 67, 69, 52, 81, 78, 58, 79]
# =======================================================================
# ========= Episode 1249 ================================================
# Total steps: 94996
# Episode rewards, last 10: [-161.05566772114321, -168.47007641330126, -255.53545882130905, -196.07101786763423, -236.50383515376933, -157.4212662408919, -198.86619198999415, -184.22495300605584, -195.04190472870903, -186.52676373028811]
# Mean over last 125 episodes: -183.288152063
# Episode lengths, last 10: [69, 58, 94, 58, 88, 54, 65, 75, 81, 78]
# =======================================================================
#
# ========= Episode 124 ================================================
# Total steps: 9740
# Episode rewards, last 10: [-165.66725107123156, -364.03300795406096, -143.94750479728009, -199.25561972404125, -149.02333791573267, -192.55318203017947, -232.36263537077755, -164.16010181468874, -196.4696607035001, -248.66518205667765]
# Mean over last 125 episodes: -202.104027327
# Episode lengths, last 10: [99, 97, 65, 76, 57, 86, 63, 90, 68, 95]
# ======================================================================
# ========= Episode 249 ================================================
# Total steps: 19353
# Episode rewards, last 10: [-300.22759657886161, -165.85540699875907, -151.32493464825632, -44.166211138664409, -155.30339319604201, -173.76908624879121, -113.79659968723854, -358.53402542329138, -201.91038801979619, -63.47059800883585]
# Mean over last 125 episodes: -180.251341377
# Episode lengths, last 10: [83, 56, 62, 86, 71, 67, 79, 89, 75, 113]
# ======================================================================
# ========= Episode 374 ================================================
# Total steps: 28853
# Episode rewards, last 10: [-174.6710726607248, -189.91796824315958, -151.28079103296341, -187.04489466219476, -168.93386973450123, -230.52095511843535, -192.47057375533635, -198.50940483874254, -152.55826904546535, -68.919699534280582]
# Mean over last 125 episodes: -185.103269632
# Episode lengths, last 10: [54, 63, 97, 85, 62, 70, 72, 57, 55, 57]
# ======================================================================
# ========= Episode 499 ================================================
# Total steps: 38473
# Episode rewards, last 10: [-192.3594743661601, -175.35229216765771, -152.00778582622564, -184.60144212531816, -163.12962341953181, -211.82117586436323, -183.03415139168195, -164.20975700643083, -167.42766638101915, -289.92142715294528]
# Mean over last 125 episodes: -184.371399835
# Episode lengths, last 10: [75, 75, 66, 94, 103, 92, 82, 72, 60, 101]
# ======================================================================
# ========= Episode 624 ================================================
# Total steps: 47911
# Episode rewards, last 10: [-152.9629051299882, -156.58446622059711, -175.24597206726096, -167.42604634543812, -49.303922989560078, -275.6506349701765, -271.95859448974181, -135.50086658333319, -129.21553516979105, -145.82652906659968]
# Mean over last 125 episodes: -185.913224337
# Episode lengths, last 10: [61, 65, 79, 65, 76, 83, 90, 60, 56, 53]
# ======================================================================
# ========= Episode 749 ================================================
# Total steps: 57224
# Episode rewards, last 10: [-178.96437331260881, -184.49858807873201, -142.71822624125866, -120.98351948576105, -161.40165424304342, -173.68370551634143, -199.67979887983719, -185.24775599422085, -222.30460085761871, -144.31279455941706]
# Mean over last 125 episodes: -184.231746344
# Episode lengths, last 10: [79, 90, 62, 53, 90, 80, 71, 67, 67, 56]
# ======================================================================
# ========= Episode 874 ================================================
# Total steps: 66883
# Episode rewards, last 10: [-162.0557139265166, -146.57437395069138, -294.48850815186086, -169.2913590795674, -144.19332491726735, -158.81309965875249, -347.02447029212033, -182.55755684252031, -160.84694073455881, -143.7990102106493]
# Mean over last 125 episodes: -184.976062381
# Episode lengths, last 10: [63, 93, 102, 91, 89, 79, 104, 66, 79, 87]
# ======================================================================
# ========= Episode 999 ================================================
# Total steps: 76427
# Episode rewards, last 10: [-245.21351565877649, -192.58478950384807, -193.35909678372482, -170.72260793507996, -276.49239745043042, -190.17732549203998, -165.1356059401044, -167.74410270236837, -171.05108057144361, -216.8967446235186]
# Mean over last 125 episodes: -179.967530613
# Episode lengths, last 10: [82, 76, 95, 66, 80, 73, 89, 91, 76, 72]
# ======================================================================
# ========= Episode 1124 ================================================
# Total steps: 85551
# Episode rewards, last 10: [-149.61694882546669, -145.58585492681573, -207.06718860737246, -155.38280558860839, -211.3224585975189, -181.93293423604311, -129.79208701877315, -129.21358539464291, -145.89886087119552, -161.11211763917498]
# Mean over last 125 episodes: -174.537912347
# Episode lengths, last 10: [56, 51, 78, 52, 70, 62, 59, 88, 82, 52]
# =======================================================================
# ========= Episode 1249 ================================================
# Total steps: 94407
# Episode rewards, last 10: [-150.55077141087932, -231.37865679457303, -144.0952135337879, -208.40995315544973, -160.23026509101831, -60.813566988620678, -154.22698609033267, -165.83979037632548, -174.31206829165103, -200.70454591926227]
# Mean over last 125 episodes: -172.479605297
# Episode lengths, last 10: [77, 65, 81, 86, 89, 61, 54, 56, 59, 88]
# =======================================================================
#
# ========= Episode 124 ================================================
# Total steps: 9576
# Episode rewards, last 10: [-139.15785721367041, -177.13291586748744, -327.22293994436069, -181.58397563251452, -135.18256006954402, -225.66882572270299, -188.05259625102113, -160.1076986483769, -218.49602374210878, -137.83690740212222]
# Mean over last 125 episodes: -206.022203905
# Episode lengths, last 10: [57, 79, 95, 64, 61, 75, 101, 94, 97, 54]
# ======================================================================
# ========= Episode 249 ================================================
# Total steps: 19414
# Episode rewards, last 10: [-343.17581816548278, -161.85051923687428, -181.86459447043848, -172.4380916381977, -252.96068471986575, -204.08852015843121, -199.51507970674766, -143.64385528310362, -222.56426245764413, -392.75645050083517]
# Mean over last 125 episodes: -192.244215616
# Episode lengths, last 10: [97, 78, 70, 92, 65, 67, 75, 67, 80, 92]
# ======================================================================
# ========= Episode 374 ================================================
# Total steps: 29170
# Episode rewards, last 10: [-259.64394156518983, -236.37335131131528, -171.60726152776658, -281.6728257703445, -196.46002927055179, -142.68355692802581, -199.27371444493889, -107.33141444232515, -185.74540234929458, -186.58696287772855]
# Mean over last 125 episodes: -180.478317668
# Episode lengths, last 10: [81, 98, 64, 98, 74, 55, 76, 62, 95, 67]
# ======================================================================
# ========= Episode 499 ================================================
# Total steps: 38872
# Episode rewards, last 10: [-208.74628175545826, -173.69408399848106, -220.99478127137465, -137.35034751630468, -162.09165392430165, -184.88367680003, -76.068884500757392, -154.52174575956721, -158.66605418026001, -192.80571128161574]
# Mean over last 125 episodes: -185.047752893
# Episode lengths, last 10: [58, 61, 73, 51, 74, 78, 77, 73, 54, 77]
# ======================================================================
# ========= Episode 624 ================================================
# Total steps: 48628
# Episode rewards, last 10: [-163.19803761996582, -79.201599149204483, -194.56895222540254, -177.91032426556058, -203.32593438922726, -187.1924921584382, -199.59919289938199, -268.18118028433082, -157.78459327910056, -148.47287391038466]
# Mean over last 125 episodes: -192.273999927
# Episode lengths, last 10: [79, 75, 79, 72, 105, 96, 69, 94, 68, 55]
# ======================================================================
# ========= Episode 749 ================================================
# Total steps: 58052
# Episode rewards, last 10: [-124.78761467481533, -209.4325767383645, -263.34542730601049, -173.7155096756974, -181.46663576940369, -184.02345137643937, -229.94535876592198, -139.59268896276049, -152.0036367659209, -32.320790056886409]
# Mean over last 125 episodes: -189.329009836
# Episode lengths, last 10: [80, 72, 83, 75, 73, 72, 97, 62, 61, 89]
# ======================================================================
# ========= Episode 874 ================================================
# Total steps: 67316
# Episode rewards, last 10: [-179.19987611130182, -207.52351976172355, -267.635060305298, -242.79594757406991, -215.65049350638827, -183.27353003709888, -185.71216534136198, -170.6857462041819, -192.51655903523431, -279.62794331950533]
# Mean over last 125 episodes: -192.054844368
# Episode lengths, last 10: [87, 76, 62, 90, 63, 61, 85, 59, 87, 95]
# ======================================================================
# ========= Episode 999 ================================================
# Total steps: 76662
# Episode rewards, last 10: [-214.31762562294423, -196.11779925481073, -174.68542168726736, -160.34803907411543, -203.01021217713148, -209.01301775204519, -157.69881095007975, -190.01628902213758, -271.66120559621743, -206.47839993247604]
# Mean over last 125 episodes: -184.008666916
# Episode lengths, last 10: [68, 66, 52, 69, 59, 73, 85, 77, 76, 85]
# ======================================================================
# ========= Episode 1124 ================================================
# Total steps: 85786
# Episode rewards, last 10: [-185.09576828067816, -191.3520697138039, -171.29984933143692, -151.94553319749477, -308.15641738556576, -241.72971227611544, -156.08440435052813, -185.03437653999882, -149.66063371954894, -137.35213363243548]
# Mean over last 125 episodes: -178.369990164
# Episode lengths, last 10: [59, 59, 53, 85, 94, 83, 83, 80, 79, 51]
# =======================================================================
# ========= Episode 1249 ================================================
# Total steps: 94867
# Episode rewards, last 10: [-195.48962363591971, -207.50535259213794, -182.8105960231313, -218.94861597794826, -163.41725803719225, -80.309267662581277, -165.16859872385999, -187.99145694059746, -187.61567018208601, -225.82663594786749]
# Mean over last 125 episodes: -180.210099811
# Episode lengths, last 10: [88, 80, 93, 59, 91, 93, 65, 89, 80, 83]
# =======================================================================

# %%
res_b = produce_experiment(DDQL, ddql_boltzman_params, ddql_train_params, 10)
# Out:
# ========= Episode 124 ================================================
# Total steps: 10910
# Episode rewards, last 10: [-271.21861664706773, -115.69065939393288, -284.42129081293785, -188.39973696329372, -153.31491147958235, -128.30006490601136, -164.36534028651775, -176.08872430386401, -223.22301220687734, -366.29984130247635]
# Mean over last 125 episodes: -234.37608379
# Episode lengths, last 10: [65, 59, 119, 84, 57, 70, 69, 62, 109, 98]
# ======================================================================
# ========= Episode 249 ================================================
# Total steps: 22597
# Episode rewards, last 10: [-83.739148095678729, -125.17415877013835, -534.1935852669485, -166.08474018886551, -268.55269136203907, -219.81425784136133, -87.520621604181201, -106.2373473657901, -30.187244425203147, -148.25204612735794]
# Mean over last 125 episodes: -228.175844611
# Episode lengths, last 10: [92, 57, 99, 88, 104, 119, 61, 113, 91, 110]
# ======================================================================
# ========= Episode 374 ================================================
# Total steps: 34019
# Episode rewards, last 10: [-434.6273927047522, -493.65175860594451, -177.58700935318976, -115.60824901056137, -364.13798074213378, -165.4186644373514, -247.67356672543403, -182.73959544243456, -420.18997362126436, -193.88706552852824]
# Mean over last 125 episodes: -238.78005657
# Episode lengths, last 10: [123, 87, 72, 94, 72, 79, 109, 75, 122, 67]
# ======================================================================
# ========= Episode 499 ================================================
# Total steps: 45456
# Episode rewards, last 10: [-124.05213851153283, -185.7760499931571, -182.77004653105473, -168.58849134553282, -502.57612210809458, -238.71258979477849, -5.9628696362349274, -385.87090820517426, -306.47801146502809, -266.73179026778712]
# Mean over last 125 episodes: -228.929071604
# Episode lengths, last 10: [112, 70, 118, 120, 85, 88, 88, 91, 90, 117]
# ======================================================================
# ========= Episode 624 ================================================
# Total steps: 56788
# Episode rewards, last 10: [-149.30473204918553, -118.7846025620714, -489.21618610740364, -483.81130249437837, -208.34108832617787, -177.6646223779023, -122.84892742296759, -208.99289710569803, -188.15548548169079, -163.84123666542405]
# Mean over last 125 episodes: -219.548423721
# Episode lengths, last 10: [94, 69, 104, 95, 106, 103, 71, 85, 72, 107]
# ======================================================================
# ========= Episode 749 ================================================
# Total steps: 68222
# Episode rewards, last 10: [-172.64737512108144, -188.7248692985828, -86.411192976095379, -284.33962452138303, -286.97670794292651, -171.80741019074179, -174.64063304965987, -383.49285371432359, -380.3430207394839, -195.48197187034765]
# Mean over last 125 episodes: -235.36621754
# Episode lengths, last 10: [122, 68, 88, 91, 118, 75, 85, 87, 94, 73]
# ======================================================================
# ========= Episode 874 ================================================
# Total steps: 79625
# Episode rewards, last 10: [-139.45179588258014, -284.60937391584946, -190.48172803413684, -144.00050110931682, -39.638891491480848, -293.67508963434273, -142.73734350827038, -199.7202243749357, -181.89843401062183, -320.20269036881314]
# Mean over last 125 episodes: -216.68733851
# Episode lengths, last 10: [97, 116, 67, 67, 132, 101, 71, 81, 74, 100]
# ======================================================================
# ========= Episode 999 ================================================
# Total steps: 90909
# Episode rewards, last 10: [-152.87109857253358, -149.0231805411841, -104.23605044468049, -383.20738301708133, -228.830917043548, -154.52201670285496, -198.38313355017181, -127.24726905301188, -150.87600813860101, -317.87641614605684]
# Mean over last 125 episodes: -225.646876629
# Episode lengths, last 10: [69, 103, 79, 76, 99, 64, 94, 62, 115, 73]
# ======================================================================
# ========= Episode 1124 ================================================
# Total steps: 101957
# Episode rewards, last 10: [-120.57355637369908, -106.12083863347988, -304.0884231155917, -184.76214463916114, -256.26058396694179, -127.91479985368733, -162.44544549287406, -287.2318755402996, -163.41734229569033, -226.87764714308139]
# Mean over last 125 episodes: -214.26887226
# Episode lengths, last 10: [61, 87, 96, 119, 63, 72, 93, 101, 64, 78]
# =======================================================================
# ========= Episode 1249 ================================================
# Total steps: 113402
# Episode rewards, last 10: [-358.88323435661692, -281.81991917964979, -224.13686245314835, -250.53707700567639, -502.35377537727123, -489.41071430720092, -377.54558809625581, -406.1877001309839, -153.31914983808952, -128.53208403250741]
# Mean over last 125 episodes: -229.377495329
# Episode lengths, last 10: [104, 72, 109, 102, 109, 89, 95, 92, 73, 82]
# =======================================================================
#
# ========= Episode 124 ================================================
# Total steps: 11073
# Episode rewards, last 10: [-412.36976002307983, -132.09371648313004, -150.1137676231225, -160.96084450746352, -176.27165393866761, -151.69901541060673, -322.91435349767823, -245.80506853830187, -112.31607098424965, -207.5224888857139]
# Mean over last 125 episodes: -208.454921469
# Episode lengths, last 10: [100, 77, 70, 68, 94, 102, 114, 106, 64, 113]
# ======================================================================
# ========= Episode 249 ================================================
# Total steps: 22682
# Episode rewards, last 10: [-245.74763437706409, -453.77769163002392, -308.59072156530374, -84.43636927097981, -244.29163779953731, -402.57546196778935, -186.6814286323694, -265.10815107304029, -222.10522259489733, -234.93442110212814]
# Mean over last 125 episodes: -221.154438722
# Episode lengths, last 10: [95, 110, 93, 67, 93, 113, 92, 95, 72, 80]
# ======================================================================
# ========= Episode 374 ================================================
# Total steps: 33840
# Episode rewards, last 10: [-125.26797443688696, -247.70679216701402, -142.25496485133684, -246.59784962512063, -520.33812734848823, -444.17587457773709, -85.582176716978623, -269.41587437496628, -377.23947939658922, -403.23629614667743]
# Mean over last 125 episodes: -231.783291856
# Episode lengths, last 10: [103, 73, 100, 99, 110, 86, 63, 77, 79, 113]
# ======================================================================
# ========= Episode 499 ================================================
# Total steps: 45553
# Episode rewards, last 10: [-141.90318966556435, -171.29562971013718, -315.65458143749993, -187.1342894153525, -130.43151681600961, -177.39532128131114, -228.06331430850824, -175.67225700955925, -114.4493001994513, -246.44855284856709]
# Mean over last 125 episodes: -239.070293834
# Episode lengths, last 10: [70, 78, 108, 95, 67, 95, 127, 58, 66, 73]
# ======================================================================
# ========= Episode 624 ================================================
# Total steps: 56623
# Episode rewards, last 10: [-207.74034138910508, -104.86553373624015, -130.86949314990613, -468.07387548469706, -341.50080728555838, -533.70481139785545, -501.0066652581591, -421.82320118034818, -274.04493537749659, -203.83548664118558]
# Mean over last 125 episodes: -224.395631054
# Episode lengths, last 10: [66, 64, 74, 84, 84, 99, 112, 127, 92, 114]
# ======================================================================
# ========= Episode 749 ================================================
# Total steps: 68090
# Episode rewards, last 10: [-151.16975951423569, -105.57988079037533, -356.96264680563195, -120.11682031038151, -170.63075627423041, -152.38977382486388, -298.38789017390184, -158.16131331289677, -154.02803963397656, -256.79364939626288]
# Mean over last 125 episodes: -227.267035246
# Episode lengths, last 10: [97, 96, 99, 77, 104, 129, 117, 80, 123, 67]
# ======================================================================
# ========= Episode 874 ================================================
# Total steps: 79621
# Episode rewards, last 10: [-218.76183753895126, -124.6896439200053, -283.88166667443284, -106.45361785804447, -475.45661630725971, -158.71835466899142, -121.30017202289949, -190.20071754479949, -28.403959067021049, -201.77220582542134]
# Mean over last 125 episodes: -217.414779122
# Episode lengths, last 10: [80, 90, 63, 126, 130, 85, 80, 79, 89, 72]
# ======================================================================
# ========= Episode 999 ================================================
# Total steps: 91019
# Episode rewards, last 10: [-267.4910646639396, -87.580282750819578, -93.85571657533113, -224.97241206775874, -258.00766958176564, -450.87129131597641, -288.33757477082077, -353.43314593846662, -125.69258243921442, -480.39946493537911]
# Mean over last 125 episodes: -224.33918698
# Episode lengths, last 10: [119, 85, 108, 68, 92, 102, 110, 78, 96, 88]
# ======================================================================
# ========= Episode 1124 ================================================
# Total steps: 102429
# Episode rewards, last 10: [-189.5136248084396, -229.55537765810587, -161.44152276045446, -257.2293519997263, -122.00268861562255, -424.0328752212771, -412.65315561347296, -286.35081737700477, -335.11211584188595, -331.32384147606638]
# Mean over last 125 episodes: -228.848688412
# Episode lengths, last 10: [83, 72, 110, 93, 99, 122, 95, 73, 93, 130]
# =======================================================================
# ========= Episode 1249 ================================================
# Total steps: 113692
# Episode rewards, last 10: [-119.44820847556068, -203.69316708228581, -143.97611515533157, -214.79190924178232, -178.030203479341, -397.28909239110521, -176.07858647742114, -148.85528485766469, -123.38174734554374, -173.40383741667119]
# Mean over last 125 episodes: -225.638420647
# Episode lengths, last 10: [77, 124, 79, 71, 78, 111, 98, 73, 79, 69]
# =======================================================================
#
# ========= Episode 124 ================================================
# Total steps: 14167
# Episode rewards, last 10: [-108.63119346918889, -63.71799575025139, -145.86148716282992, -79.819284176654179, -117.60612670247002, -102.01208939265555, -103.87094117989565, -100.3063998315683, -171.55213757291557, -163.1274717144621]
# Mean over last 125 episodes: -190.549633955
# Episode lengths, last 10: [55, 67, 88, 98, 91, 129, 167, 74, 118, 119]
# ======================================================================
# ========= Episode 249 ================================================
# Total steps: 31496
# Episode rewards, last 10: [-62.797648053348141, -24.197228625219196, 7.5571154387930992, 41.000786781759089, -837.96250898891662, -274.68491855733373, -143.15630180319525, -144.84302643107651, -545.32794238566862, -70.748139277412662]
# Mean over last 125 episodes: -159.872433279
# Episode lengths, last 10: [189, 162, 199, 199, 176, 135, 69, 199, 94, 160]
# ======================================================================
# ========= Episode 374 ================================================
# Total steps: 49793
# Episode rewards, last 10: [-76.265107357172667, -158.88296889203025, -365.90065109645803, -128.04325226678372, -160.19987253802782, -318.76067307806181, -161.842353900723, -80.391463201002381, -65.467015182334364, -57.348142995168942]
# Mean over last 125 episodes: -136.838113844
# Episode lengths, last 10: [151, 61, 135, 112, 95, 127, 110, 102, 199, 118]
# ======================================================================
# ========= Episode 499 ================================================
# Total steps: 66385
# Episode rewards, last 10: [-144.10243620574013, -201.64955063926828, -136.74426234770476, -289.73392013347916, -125.42502768253804, -113.17650253839201, -120.46049781703587, -132.90628844442912, -288.92021853625465, -69.792630489665441]
# Mean over last 125 episodes: -144.063388967
# Episode lengths, last 10: [73, 194, 113, 118, 61, 94, 99, 132, 118, 138]
# ======================================================================
# ========= Episode 624 ================================================
# Total steps: 83821
# Episode rewards, last 10: [-163.27203462547888, -145.93788812081425, -76.10801693763068, -80.42410432694976, -77.613411050769443, 65.697572084537128, -75.800977823473303, -417.54688255345343, -141.10271756161063, -175.81640787859163]
# Mean over last 125 episodes: -101.580126647
# Episode lengths, last 10: [67, 123, 90, 114, 114, 199, 156, 89, 71, 87]
# ======================================================================
# ========= Episode 749 ================================================
# Total steps: 100193
# Episode rewards, last 10: [-197.40970550873215, -162.12772369617321, -122.12929506903455, -65.855566385278223, -11.124442578261551, -172.97746488001911, -29.8037993465352, -23.027882571681872, -76.067703994008212, -109.27070099635017]
# Mean over last 125 episodes: -109.559606215
# Episode lengths, last 10: [93, 114, 145, 199, 106, 69, 125, 119, 199, 79]
# ======================================================================
# ========= Episode 874 ================================================
# Total steps: 117074
# Episode rewards, last 10: [-130.49032066512891, -90.447254503382482, 106.64019775068891, -90.546709598962451, -72.186103200855229, -65.705777530744342, -133.11027230076306, -139.74260961695762, -255.09314779498041, -259.35242131998746]
# Mean over last 125 episodes: -112.7441543
# Episode lengths, last 10: [97, 181, 199, 89, 143, 143, 124, 109, 149, 125]
# ======================================================================
# ========= Episode 999 ================================================
# Total steps: 134582
# Episode rewards, last 10: [-194.33365785582339, -178.28896707116917, -131.8108981914398, -141.09478954825613, -210.8370531194798, -181.29794988988652, -120.13148312293609, 29.253928233690694, 16.03320718899807, -239.29962087438705]
# Mean over last 125 episodes: -86.9733691178
# Episode lengths, last 10: [99, 120, 95, 77, 122, 138, 157, 199, 199, 108]
# ======================================================================
# ========= Episode 1124 ================================================
# Total steps: 149530
# Episode rewards, last 10: [-191.25209268400909, -148.86824420654136, -71.069009881868084, -401.27136254356896, -134.62229814865009, -117.19619624586969, -163.22256276436164, -26.386681934405843, -319.57471831083529, -170.40771548610928]
# Mean over last 125 episodes: -176.209874777
# Episode lengths, last 10: [144, 183, 199, 117, 90, 107, 65, 145, 109, 123]
# =======================================================================
# ========= Episode 1249 ================================================
# Total steps: 165715
# Episode rewards, last 10: [-154.17470686873247, -183.29936566204441, -142.94423675506215, -147.16345733062104, -106.77182424507585, -197.64374801218329, -444.05583193577223, -188.26311841252101, -154.67337577717734, -191.06765721580271]
# Mean over last 125 episodes: -158.903886781
# Episode lengths, last 10: [132, 135, 111, 115, 60, 114, 106, 130, 153, 98]
# =======================================================================
#
# ========= Episode 124 ================================================
# Total steps: 11356
# Episode rewards, last 10: [-199.50295027248382, -180.13921980115578, -138.03623014662693, -474.31171869572813, -110.38413999099119, -99.982803482602066, -263.87806025832168, -143.19126178297074, -34.270382028854485, -70.282680872810289]
# Mean over last 125 episodes: -247.967071393
# Episode lengths, last 10: [109, 110, 72, 103, 61, 59, 88, 122, 63, 165]
# ======================================================================
# ========= Episode 249 ================================================
# Total steps: 22758
# Episode rewards, last 10: [-180.18123861032467, -388.39407587922574, -155.68898304656679, -155.49494143027147, -404.96831990306146, -300.36095701846256, -318.43815951703732, -356.27630865404126, -108.03310821168859, -398.99592702928544]
# Mean over last 125 episodes: -243.609054532
# Episode lengths, last 10: [91, 101, 87, 86, 89, 79, 127, 123, 63, 96]
# ======================================================================
# ========= Episode 374 ================================================
# Total steps: 34347
# Episode rewards, last 10: [-200.0648149459991, -407.64836909769184, -459.83180782153363, -148.91537291306909, -241.73239017487199, -415.23357378898231, -334.98584273945767, -157.63753634625289, -299.77213190338659, -106.42940143689295]
# Mean over last 125 episodes: -231.38129505
# Episode lengths, last 10: [93, 115, 112, 66, 128, 111, 108, 118, 86, 62]
# ======================================================================
# ========= Episode 499 ================================================
# Total steps: 45929
# Episode rewards, last 10: [-277.67035609927029, -147.76937596903764, -158.1561623249884, -231.00991744229745, -152.53151141858206, -131.24907820761999, -209.32822205778797, -117.85101252025777, -436.0004623550065, -408.95784300226313]
# Mean over last 125 episodes: -232.336451449
# Episode lengths, last 10: [94, 65, 68, 120, 92, 73, 95, 119, 96, 96]
# ======================================================================
# ========= Episode 624 ================================================
# Total steps: 57692
# Episode rewards, last 10: [-251.87157758851404, -164.86492950402993, -158.35485019530245, -143.5162517115337, -257.52969411890911, -157.60659206501649, -395.69751139585185, -216.31027372602739, -144.2881528510737, -486.91048136944869]
# Mean over last 125 episodes: -229.494573453
# Episode lengths, last 10: [73, 87, 73, 85, 88, 84, 90, 111, 59, 95]
# ======================================================================
# ========= Episode 749 ================================================
# Total steps: 69001
# Episode rewards, last 10: [-186.73867006681087, -579.54376541745216, -157.45070706221333, -140.61180910199602, -309.14009409704215, -152.44636026471412, -244.26868338152238, -207.42314318312481, -1.7099018697108761, -202.26832432446486]
# Mean over last 125 episodes: -230.207314093
# Episode lengths, last 10: [64, 119, 65, 66, 113, 119, 97, 112, 76, 61]
# ======================================================================
# ========= Episode 874 ================================================
# Total steps: 80330
# Episode rewards, last 10: [-140.34483099850902, -236.21648387941639, -168.16505469947123, -558.93295799984605, -188.62715202196827, -138.92708406026253, -173.69192814488713, -224.15990734289917, -402.47184769467367, -168.47662887917139]
# Mean over last 125 episodes: -244.115130273
# Episode lengths, last 10: [83, 81, 105, 109, 141, 116, 74, 91, 108, 82]
# ======================================================================
# ========= Episode 999 ================================================
# Total steps: 92016
# Episode rewards, last 10: [-134.65920456105542, -168.75305725965364, -244.8278766143082, -242.01154023992845, -328.99426029928986, -393.88211366843115, -114.28116537882342, -160.18396084699617, -225.74801836546294, -142.23052599060415]
# Mean over last 125 episodes: -235.306212409
# Episode lengths, last 10: [95, 72, 108, 98, 115, 101, 62, 79, 70, 109]
# ======================================================================
# ========= Episode 1124 ================================================
# Total steps: 103305
# Episode rewards, last 10: [-282.34838220628035, -148.73422844182949, -201.78153382195057, -384.62561917216476, -204.35642818628912, -146.73262526169509, -162.12006851555282, -172.5194849421739, -103.52770309001643, -205.77018232896438]
# Mean over last 125 episodes: -242.621111688
# Episode lengths, last 10: [88, 90, 80, 86, 111, 60, 67, 103, 72, 72]
# =======================================================================
# ========= Episode 1249 ================================================
# Total steps: 114524
# Episode rewards, last 10: [-183.7333210624831, -166.8673794264248, -173.1190799374599, -434.27669882427, -120.81268584355337, -223.59582957671196, -129.22131738669486, -243.12677762802562, -289.00016307777901, -411.19444734930335]
# Mean over last 125 episodes: -225.436665042
# Episode lengths, last 10: [60, 74, 88, 94, 62, 90, 78, 90, 81, 77]
# =======================================================================
#
# ========= Episode 124 ================================================
# Total steps: 11171
# Episode rewards, last 10: [-195.57482337865605, -190.07470229076233, -50.456880149716497, -157.24323344080693, -389.85630719220302, -512.51530083875889, -188.52620822828902, -173.97541298020525, -126.80603783379215, -192.63714540022363]
# Mean over last 125 episodes: -235.610920395
# Episode lengths, last 10: [85, 97, 92, 79, 88, 87, 87, 68, 82, 68]
# ======================================================================
# ========= Episode 249 ================================================
# Total steps: 22633
# Episode rewards, last 10: [-164.62309293654926, -358.83372420734742, -73.34396168865338, -186.34779585046874, -94.590796130667655, -127.34569329681678, -128.47156074898876, -189.01263072377216, -85.699953203303551, -454.97662462729051]
# Mean over last 125 episodes: -224.340530374
# Episode lengths, last 10: [103, 90, 123, 92, 59, 84, 65, 134, 69, 104]
# ======================================================================
# ========= Episode 374 ================================================
# Total steps: 33951
# Episode rewards, last 10: [-87.10781081277969, -186.3461968635699, -319.78761138461971, -234.95857331956239, -295.15347477711578, -184.53430884773383, -162.24497142656691, -196.88985069816488, -324.96505817037132, -402.70896059355744]
# Mean over last 125 episodes: -232.849117022
# Episode lengths, last 10: [109, 113, 110, 116, 96, 87, 90, 68, 111, 86]
# ======================================================================
# ========= Episode 499 ================================================
# Total steps: 45160
# Episode rewards, last 10: [-225.96190446268679, -269.01418110811454, -310.90058718683736, -181.80026912104552, -192.63732646265922, -182.23343995746808, -439.33913554935975, -159.72128352368728, -87.796891577531596, -171.58584612912824]
# Mean over last 125 episodes: -227.791389291
# Episode lengths, last 10: [91, 67, 79, 95, 64, 64, 74, 98, 78, 89]
# ======================================================================
# ========= Episode 624 ================================================
# Total steps: 56800
# Episode rewards, last 10: [-195.33335821325551, -181.90070517181545, -452.62498435051401, -242.46758127443158, -455.712706862419, -140.97808029249262, -418.9533532057481, -121.90647798617326, -169.42054674714575, -180.60125721974293]
# Mean over last 125 episodes: -205.179997837
# Episode lengths, last 10: [120, 81, 78, 137, 143, 78, 97, 68, 113, 86]
# ======================================================================
# ========= Episode 749 ================================================
# Total steps: 68373
# Episode rewards, last 10: [-238.89644805034288, -164.65965465765771, -161.74243671244287, -158.02952344370618, -165.01456626555824, -137.52735735155409, -13.618973090131945, -133.72100954374139, -258.64431992901291, -393.01878284368087]
# Mean over last 125 episodes: -227.708950225
# Episode lengths, last 10: [74, 111, 67, 103, 61, 67, 144, 69, 107, 98]
# ======================================================================
# ========= Episode 874 ================================================
# Total steps: 79537
# Episode rewards, last 10: [-368.42121152159132, -218.54042789916338, -140.88199440264, -152.71089216381367, -263.03783571776091, -270.43898503863727, -345.43870119445512, -152.1838362201957, -204.80607426639602, -164.14072684380886]
# Mean over last 125 episodes: -230.214274034
# Episode lengths, last 10: [94, 119, 79, 62, 117, 89, 100, 99, 82, 126]
# ======================================================================
# ========= Episode 999 ================================================
# Total steps: 91073
# Episode rewards, last 10: [-148.81583923816714, -168.38378155963676, -238.32997386339787, -134.97069909150096, -356.19525876079956, -151.10683234390291, -58.044841969162192, -302.60423725392343, -109.20579411368685, -414.11903628805175]
# Mean over last 125 episodes: -232.241836011
# Episode lengths, last 10: [102, 95, 100, 78, 98, 99, 73, 121, 65, 87]
# ======================================================================
# ========= Episode 1124 ================================================
# Total steps: 102636
# Episode rewards, last 10: [-180.36416367951449, -174.17716804155839, -173.34525262126161, -385.3905191217799, -143.5205113744247, -552.83829770744819, -180.47981324355729, -150.39969657655598, -277.92176930464268, -141.03475191938585]
# Mean over last 125 episodes: -239.29340161
# Episode lengths, last 10: [97, 85, 74, 107, 69, 89, 134, 121, 78, 70]
# =======================================================================
# ========= Episode 1249 ================================================
# Total steps: 113758
# Episode rewards, last 10: [-285.98823316854595, -348.835394877944, -206.251742805422, -132.10037014062453, -243.98473717281516, -279.02367776440371, -279.93293384949152, -180.50019396969174, -206.76744044712524, -252.92346921458528]
# Mean over last 125 episodes: -221.541910861
# Episode lengths, last 10: [81, 78, 71, 88, 87, 120, 86, 103, 64, 120]
# =======================================================================
#
# ========= Episode 124 ================================================
# Total steps: 14705
# Episode rewards, last 10: [-170.76631093547775, -184.10850598066361, -165.57921933948387, -136.14153020041806, -224.24780674065528, -246.87262227751768, -92.267844427767571, -197.37720591116869, -28.966587315076239, -163.31442014270888]
# Mean over last 125 episodes: -191.374741474
# Episode lengths, last 10: [87, 97, 118, 133, 144, 117, 95, 99, 108, 168]
# ======================================================================
# ========= Episode 249 ================================================
# Total steps: 33294
# Episode rewards, last 10: [-77.427802983141504, -147.0045573351095, -141.0585390353362, -168.39984566151048, -126.61276362994334, -128.82497838260633, -71.203474520402622, -25.006319875156485, -58.610810790922294, -134.24723591150638]
# Mean over last 125 episodes: -137.016083531
# Episode lengths, last 10: [94, 79, 151, 88, 95, 163, 198, 199, 122, 73]
# ======================================================================
# ========= Episode 374 ================================================
# Total steps: 52478
# Episode rewards, last 10: [-64.189492333055313, -59.185088166903242, -39.451600610376218, -7.9996047186624111, -16.270984859701471, -153.09730191958118, 67.707982609845473, -151.77750634945508, -146.29538566536422, -69.179974190409354]
# Mean over last 125 episodes: -65.557686542
# Episode lengths, last 10: [105, 142, 114, 96, 187, 112, 199, 189, 81, 105]
# ======================================================================
# ========= Episode 499 ================================================
# Total steps: 72852
# Episode rewards, last 10: [-13.328929857097734, -133.64427911824228, -107.55831159784958, 125.37497464861457, 85.722642614896003, -78.715698935040706, -3.5752509952526532, -73.416281018225177, 23.901720708857642, -140.4842228036828]
# Mean over last 125 episodes: -45.8466308839
# Episode lengths, last 10: [187, 111, 93, 199, 199, 119, 199, 187, 199, 108]
# ======================================================================
# ========= Episode 624 ================================================
# Total steps: 89206
# Episode rewards, last 10: [-85.588569243076208, -124.54318151094316, -89.125381881543788, -69.748901894839278, -23.425065056168265, -151.66499595067273, -173.4773724137801, -112.67747622954532, -58.177377637976988, -137.86858048025618]
# Mean over last 125 episodes: -118.419730554
# Episode lengths, last 10: [179, 88, 92, 127, 171, 125, 81, 100, 114, 119]
# ======================================================================
# ========= Episode 749 ================================================
# Total steps: 106240
# Episode rewards, last 10: [-149.58107460692165, -142.13761935361768, -4.4813779068550312, 12.433340521318119, -116.55236998371689, -40.838344578324175, -171.35565537965684, -130.00508210646089, -56.141748109491381, -50.846772660384715]
# Mean over last 125 episodes: -92.4366273425
# Episode lengths, last 10: [83, 96, 199, 199, 119, 199, 190, 65, 145, 108]
# ======================================================================
# ========= Episode 874 ================================================
# Total steps: 126344
# Episode rewards, last 10: [-89.775877758408427, -51.40926853041438, 100.20472172105298, -76.142951784456457, 75.970405022529363, 56.631194649280644, -43.575515185192913, 62.88654810721517, 50.47510941053001, -96.595381085648185]
# Mean over last 125 episodes: -58.5152300141
# Episode lengths, last 10: [135, 192, 199, 137, 199, 199, 173, 199, 199, 199]
# ======================================================================
# ========= Episode 999 ================================================
# Total steps: 143758
# Episode rewards, last 10: [-118.52203354021626, 39.526908117011622, -98.06628213724116, -66.308350720449255, -80.794474348437475, -148.06279125120301, -141.21642824315259, -464.35694874342806, -164.51475700399976, 12.53406035502957]
# Mean over last 125 episodes: -80.8095261982
# Episode lengths, last 10: [152, 199, 189, 194, 96, 128, 94, 163, 120, 199]
# ======================================================================
# ========= Episode 1124 ================================================
# Total steps: 162604
# Episode rewards, last 10: [-89.461249907879946, -85.394800287864271, -76.075482811698549, -18.83439138771773, -54.872414505025084, 90.404317939652344, 118.96180323221139, -49.937476764245758, -46.019638274489921, -876.66670246968852]
# Mean over last 125 episodes: -49.4382653617
# Episode lengths, last 10: [94, 101, 92, 119, 194, 199, 199, 88, 139, 183]
# =======================================================================
# ========= Episode 1249 ================================================
# Total steps: 180217
# Episode rewards, last 10: [-133.69072029528922, -310.3775150798557, -366.54531965885656, -161.16354752650926, -192.80660321985829, -157.03678343799726, -129.93511983748348, -122.68425849903753, -243.12184797681877, -160.94172793637881]
# Mean over last 125 episodes: -99.583968566
# Episode lengths, last 10: [70, 128, 114, 90, 90, 115, 64, 59, 104, 110]
# =======================================================================
#
# ========= Episode 124 ================================================
# Total steps: 10508
# Episode rewards, last 10: [-156.49154634421944, -126.86492794960162, -336.47450795357082, -316.22446967478788, -217.58972223647322, -113.18488362910378, -159.71085266730671, -195.14667281987562, -223.56886676700378, -131.33284964388051]
# Mean over last 125 episodes: -221.005091545
# Episode lengths, last 10: [63, 102, 89, 99, 97, 73, 67, 81, 61, 69]
# ======================================================================
# ========= Episode 249 ================================================
# Total steps: 21808
# Episode rewards, last 10: [-144.90108925218567, -118.60404158516018, -156.85203170777694, -176.56039645660135, -520.17376280884605, -176.9471279587255, -142.87425317821641, -265.15384628225155, -156.65523463401138, -164.81505620333235]
# Mean over last 125 episodes: -226.393593262
# Episode lengths, last 10: [92, 64, 66, 90, 118, 114, 112, 107, 57, 107]
# ======================================================================
# ========= Episode 374 ================================================
# Total steps: 33279
# Episode rewards, last 10: [-279.99034186626477, -191.06909021881356, -231.59865168995236, -311.83463373617104, -215.85453328532853, -162.31489331718441, -259.26243207686787, -131.49722066677506, -151.95913081256128, -126.83914235588033]
# Mean over last 125 episodes: -222.983343081
# Episode lengths, last 10: [98, 101, 95, 77, 55, 63, 67, 60, 112, 62]
# ======================================================================
# ========= Episode 499 ================================================
# Total steps: 44799
# Episode rewards, last 10: [-166.25112120920272, -245.32435728911543, -130.32779137469845, -165.72034068566245, -340.70905510282375, -397.51463244160851, -131.03754322196812, -151.09627397723034, -130.75186118645189, -133.56770948305945]
# Mean over last 125 episodes: -228.21439919
# Episode lengths, last 10: [82, 77, 107, 84, 116, 83, 103, 112, 69, 123]
# ======================================================================
# ========= Episode 624 ================================================
# Total steps: 56169
# Episode rewards, last 10: [-142.94152429588885, -226.24508572350334, -249.55533658726884, -273.20932098398498, -363.02844779546569, -427.59058696325843, -190.92080870484165, -226.98528245302802, -405.93312442001201, -164.72502298895267]
# Mean over last 125 episodes: -236.633823284
# Episode lengths, last 10: [81, 54, 69, 77, 73, 83, 72, 87, 86, 68]
# ======================================================================
# ========= Episode 749 ================================================
# Total steps: 67806
# Episode rewards, last 10: [-298.58417524571513, -140.55341444687144, -108.15150569723247, -175.97517834482164, -276.18419708219443, -356.4354049535346, -139.46671049258717, -186.55637880306028, -312.42175397489888, -480.44528952623079]
# Mean over last 125 episodes: -226.222480531
# Episode lengths, last 10: [121, 75, 70, 98, 105, 120, 69, 100, 68, 87]
# ======================================================================
# ========= Episode 874 ================================================
# Total steps: 79303
# Episode rewards, last 10: [-224.91330154639655, -118.02881845836086, -160.16180327077421, -354.52611770707927, -263.60354555274841, -115.6131243264407, -177.31011209440481, -395.61326458968881, -134.54916978116503, -343.00503318750447]
# Mean over last 125 episodes: -217.43358532
# Episode lengths, last 10: [95, 71, 64, 94, 67, 113, 88, 99, 68, 97]
# ======================================================================
# ========= Episode 999 ================================================
# Total steps: 90720
# Episode rewards, last 10: [-292.578052330182, -191.05779292236224, -485.14741308901966, -290.35347312768755, -136.29090515911059, -176.74096842218759, -171.84771693432069, -173.3164309785092, -156.71055648866144, -327.1406768352532]
# Mean over last 125 episodes: -224.603544445
# Episode lengths, last 10: [94, 114, 101, 97, 95, 108, 88, 76, 91, 79]
# ======================================================================
# ========= Episode 1124 ================================================
# Total steps: 102119
# Episode rewards, last 10: [-254.40366158319625, -147.39350557123663, -468.766818488372, -89.59304917863642, -154.42711385074213, -175.854575413817, -223.47621185548653, -306.47369205319484, -151.50934286766505, -152.79700275181625]
# Mean over last 125 episodes: -234.085032405
# Episode lengths, last 10: [97, 72, 110, 126, 67, 94, 75, 106, 70, 99]
# =======================================================================
# ========= Episode 1249 ================================================
# Total steps: 113921
# Episode rewards, last 10: [-351.57278413797587, -268.21500265120028, -423.32986880389433, -72.467956355987425, -189.38115223430913, -326.15873748460126, -315.70975814405227, -407.05231067972193, -165.40886186526825, -339.55266876571341]
# Mean over last 125 episodes: -235.454304239
# Episode lengths, last 10: [96, 100, 98, 96, 82, 95, 82, 101, 94, 73]
# =======================================================================
#
# ========= Episode 124 ================================================
# Total steps: 11376
# Episode rewards, last 10: [-148.89434610022857, -459.19069613122593, -456.03706688029035, -272.63073608795924, -232.55899947470419, -346.7652217085174, -108.41452635328757, -153.65831673910156, -166.13405566193842, -166.20985592348524]
# Mean over last 125 episodes: -221.234313768
# Episode lengths, last 10: [68, 110, 102, 140, 82, 109, 103, 115, 73, 71]
# ======================================================================
# ========= Episode 249 ================================================
# Total steps: 22753
# Episode rewards, last 10: [-316.536967993362, -161.05478846316907, -126.89488496319539, -295.25318283696151, -475.58152802896745, -192.17263386467388, -185.27724434006416, -139.03366157810768, -416.88342045749681, -176.27997454680684]
# Mean over last 125 episodes: -245.686585789
# Episode lengths, last 10: [73, 81, 75, 74, 95, 68, 68, 73, 106, 90]
# ======================================================================
# ========= Episode 374 ================================================
# Total steps: 34459
# Episode rewards, last 10: [-147.05836446663614, -35.189581615210415, -138.95935144093605, -113.14243563601296, -377.96446221345531, -233.41613971307356, -155.71012128524859, -151.81658335837963, -125.61405950368389, -115.08826694429195]
# Mean over last 125 episodes: -212.008029883
# Episode lengths, last 10: [86, 139, 71, 67, 98, 85, 78, 76, 78, 62]
# ======================================================================
# ========= Episode 499 ================================================
# Total steps: 45744
# Episode rewards, last 10: [-270.23918291698942, -126.22697443446398, -150.77926744127171, -538.61646429427606, -497.55683222083439, -347.79236958713989, -187.82939744206953, -247.07428181349539, -139.82492638906848, -335.88555213434063]
# Mean over last 125 episodes: -224.526895139
# Episode lengths, last 10: [89, 61, 76, 102, 117, 103, 58, 85, 84, 76]
# ======================================================================
# ========= Episode 624 ================================================
# Total steps: 57094
# Episode rewards, last 10: [-331.23055231612938, -148.03778991230962, -392.69425583831588, -218.04261654231163, -351.89088180850331, -164.75285145130135, -208.48167823998881, -169.27356709098686, -105.56072207956416, -245.55992323346769]
# Mean over last 125 episodes: -242.332874688
# Episode lengths, last 10: [133, 68, 79, 80, 92, 106, 97, 138, 65, 70]
# ======================================================================
# ========= Episode 749 ================================================
# Total steps: 68615
# Episode rewards, last 10: [-349.30353767855115, -147.3232583642253, -188.26103358086257, -286.41260038347536, -331.93962986517909, -192.56880297175076, -154.01062000236664, -381.44143086963908, -369.81301822691483, -59.080436198141378]
# Mean over last 125 episodes: -241.402882708
# Episode lengths, last 10: [95, 79, 107, 73, 71, 84, 76, 100, 121, 86]
# ======================================================================
# ========= Episode 874 ================================================
# Total steps: 80189
# Episode rewards, last 10: [-147.62359167446732, -139.84351460296716, -163.73582103799026, -393.41224799413521, -145.89156538956564, -144.69847630855801, -244.47465499965026, -404.06566322092146, -546.73161222142733, -314.71846651540682]
# Mean over last 125 episodes: -241.245875484
# Episode lengths, last 10: [89, 76, 68, 120, 67, 122, 112, 114, 128, 82]
# ======================================================================
# ========= Episode 999 ================================================
# Total steps: 91655
# Episode rewards, last 10: [-357.73495906090943, -149.22783388606175, -255.35153731306264, -235.62919636787117, -304.21011215952666, -154.9725416015865, -153.70478145938426, -169.1153050073903, -84.154628514654775, -113.82713055066361]
# Mean over last 125 episodes: -226.755813593
# Episode lengths, last 10: [107, 101, 100, 73, 102, 73, 55, 68, 105, 59]
# ======================================================================
# ========= Episode 1124 ================================================
# Total steps: 103579
# Episode rewards, last 10: [-274.90360359286751, -263.3911439756024, -122.45183750982747, -243.10852304848683, -503.84209683214391, -239.39128883021439, -169.69798084766893, -167.30408174882203, -171.81399782678574, -268.88195320346267]
# Mean over last 125 episodes: -226.3267488
# Episode lengths, last 10: [87, 71, 75, 62, 140, 111, 70, 98, 88, 61]
# =======================================================================
# ========= Episode 1249 ================================================
# Total steps: 114919
# Episode rewards, last 10: [-152.76942884543905, -192.676484513015, -148.92311863572047, -368.08349467495231, -198.8356247913816, -135.18829639388628, -169.49441248550042, -200.68758890065305, -84.168737157974007, -170.37418000912584]
# Mean over last 125 episodes: -228.085885034
# Episode lengths, last 10: [113, 83, 100, 89, 73, 108, 96, 86, 126, 97]
# =======================================================================
#
# ========= Episode 124 ================================================
# Total steps: 10518
# Episode rewards, last 10: [-233.12634896838949, -222.90038463985934, -103.82747198330853, -117.9767505837462, -201.68183936447241, 56.644996723258458, -66.043130390269809, -281.45326413088947, -130.29917282534552, -482.06274624819031]
# Mean over last 125 episodes: -212.831004774
# Episode lengths, last 10: [98, 64, 69, 69, 62, 199, 73, 125, 67, 88]
# ======================================================================
# ========= Episode 249 ================================================
# Total steps: 21837
# Episode rewards, last 10: [-137.38508190691812, -107.22836408530998, -127.71211748176081, -157.23996387650584, -178.93693568509795, -237.9990455748397, -331.08559968612371, -317.07047380117365, -21.21056529308774, -140.42019143211371]
# Mean over last 125 episodes: -220.689105945
# Episode lengths, last 10: [73, 118, 136, 80, 87, 96, 74, 120, 90, 67]
# ======================================================================
# ========= Episode 374 ================================================
# Total steps: 32751
# Episode rewards, last 10: [-90.206566842754512, -176.94790701555104, -311.0538472508884, -440.25301726476738, -207.04146333851349, -179.31044003649208, -377.8149582843044, -252.0455333413552, -182.77456300692421, -212.53173949599636]
# Mean over last 125 episodes: -217.980466533
# Episode lengths, last 10: [80, 81, 98, 87, 105, 68, 85, 83, 79, 113]
# ======================================================================
# ========= Episode 499 ================================================
# Total steps: 44216
# Episode rewards, last 10: [-459.91551944522507, -162.53398976493389, -157.22556576557139, -289.49773491930659, -276.18441763133842, -525.65668975238646, -65.084504401538496, -136.38769397445222, -203.76397119276527, -338.30824571474591]
# Mean over last 125 episodes: -231.824648712
# Episode lengths, last 10: [97, 106, 83, 111, 105, 115, 82, 100, 84, 117]
# ======================================================================
# ========= Episode 624 ================================================
# Total steps: 55590
# Episode rewards, last 10: [-353.625645202577, -259.86196554260175, -266.08043334157912, -197.60436449599888, -207.39821631661567, -196.10288457049194, -177.64917495398032, -301.45111294691031, -134.59742833863427, -157.14356189497323]
# Mean over last 125 episodes: -222.569136254
# Episode lengths, last 10: [93, 102, 73, 80, 75, 161, 81, 61, 70, 68]
# ======================================================================
# ========= Episode 749 ================================================
# Total steps: 66962
# Episode rewards, last 10: [-129.54839739134053, -252.65138165954716, -192.0340549867293, -358.4926104358467, -111.22810737462021, -226.90871670522282, -167.96216592167804, -178.07557804456138, -223.96115175528766, -260.706309477481]
# Mean over last 125 episodes: -228.879578338
# Episode lengths, last 10: [103, 61, 83, 124, 79, 67, 122, 126, 115, 68]
# ======================================================================
# ========= Episode 874 ================================================
# Total steps: 78666
# Episode rewards, last 10: [-165.57376793731117, -163.31982027972893, -186.82961925733525, -163.92781300792223, -135.83854742700032, -362.5740385872831, -240.71991013238778, -238.04558513414892, -197.03380651519183, -173.53403334689949]
# Mean over last 125 episodes: -222.650094747
# Episode lengths, last 10: [120, 76, 69, 135, 102, 83, 127, 107, 69, 113]
# ======================================================================
# ========= Episode 999 ================================================
# Total steps: 90177
# Episode rewards, last 10: [-391.41761812719636, -449.77759730143811, -312.86862218045667, -323.65124284840027, -383.21028617530885, -131.48340881676393, -152.49981143128457, -208.77378227442998, -30.066612744170328, -142.44595244582996]
# Mean over last 125 episodes: -246.628977383
# Episode lengths, last 10: [99, 89, 73, 71, 103, 71, 71, 123, 129, 69]
# ======================================================================
# ========= Episode 1124 ================================================
# Total steps: 101690
# Episode rewards, last 10: [-429.54259531996047, -80.050491755548222, -125.26201630994677, -134.98019837379059, -108.29750268594954, -479.6401241380629, -244.03413462403068, -189.23159350222886, -360.06538264909284, -386.56033651567304]
# Mean over last 125 episodes: -230.288661898
# Episode lengths, last 10: [118, 106, 57, 67, 73, 103, 67, 65, 67, 115]
# =======================================================================
# ========= Episode 1249 ================================================
# Total steps: 113435
# Episode rewards, last 10: [-155.29677354770854, -135.98071938171893, -238.28808900529711, -484.47975379139416, -158.4051463143731, -280.12789243117095, -302.16427957706401, -232.97286504370015, -147.29259198259524, 7.5518872880724643]
# Mean over last 125 episodes: -214.717185192
# Episode lengths, last 10: [80, 57, 109, 96, 129, 120, 102, 77, 86, 78]
# =======================================================================
#
# ========= Episode 124 ================================================
# Total steps: 14699
# Episode rewards, last 10: [-138.88079713899879, -164.86805786057295, -143.88754010218929, -141.18203865687508, -422.83995342401425, -108.4551407342401, -174.882667239429, -169.40293167299259, 21.349527717124264, -52.459089608652526]
# Mean over last 125 episodes: -213.993471776
# Episode lengths, last 10: [87, 141, 129, 174, 105, 182, 144, 115, 199, 199]
# ======================================================================
# ========= Episode 249 ================================================
# Total steps: 33449
# Episode rewards, last 10: [-133.00327513687267, -142.38866595103065, -204.36177391174118, -39.303472392273605, -90.844149645456369, -90.752772352761568, 3.1058537981199299, -55.934482045139077, -67.257362594475026, -97.999981046259563]
# Mean over last 125 episodes: -135.766447754
# Episode lengths, last 10: [82, 108, 114, 108, 96, 158, 199, 199, 111, 108]
# ======================================================================
# ========= Episode 374 ================================================
# Total steps: 51501
# Episode rewards, last 10: [-218.45488674835377, -27.559848190853746, -224.63729908489265, -173.92942549227428, -148.22259954323354, -43.028165844871225, -391.09796821794305, -282.89897640341286, -113.99914286120331, -80.052375263092813]
# Mean over last 125 episodes: -110.38289255
# Episode lengths, last 10: [129, 199, 114, 125, 104, 188, 127, 145, 96, 199]
# ======================================================================
# ========= Episode 499 ================================================
# Total steps: 67998
# Episode rewards, last 10: [-70.379686228265825, -128.69030518444691, -119.74644342100618, -175.25746490431823, -167.55220973680827, -22.378900822583489, -97.08941771770202, -69.532761582213567, -62.995791635837733, -95.872193114980377]
# Mean over last 125 episodes: -96.7430082142
# Episode lengths, last 10: [114, 64, 117, 138, 92, 180, 129, 127, 199, 164]
# ======================================================================
# ========= Episode 624 ================================================
# Total steps: 86078
# Episode rewards, last 10: [103.38630859062987, 29.176303166910369, -105.88185531623952, -140.06423780909745, -82.825206391808734, -87.122481881805356, -61.545266728526244, -36.723287431197043, -82.820903431060543, -60.722794213721016]
# Mean over last 125 episodes: -68.4469898599
# Episode lengths, last 10: [199, 199, 102, 79, 114, 134, 157, 103, 103, 160]
# ======================================================================
# ========= Episode 749 ================================================
# Total steps: 103732
# Episode rewards, last 10: [-44.243545460316341, -13.622969703940242, -89.339727961656465, -60.106846381832788, -64.423774325011266, -92.485331322819022, -29.501149188289105, -55.409560727336967, 99.139146765262993, 9.9039293849225434]
# Mean over last 125 episodes: -54.6152429407
# Episode lengths, last 10: [140, 162, 181, 158, 140, 156, 125, 116, 199, 199]
# ======================================================================
# ========= Episode 874 ================================================
# Total steps: 121042
# Episode rewards, last 10: [-187.69425886027216, -530.23670974593233, -161.21252654394428, -76.804143139816134, -119.70316788606338, -143.92089556964987, -116.26207378427142, -275.25958634250765, -155.96615660852041, -561.82660648089734]
# Mean over last 125 episodes: -76.1630777428
# Episode lengths, last 10: [192, 138, 98, 147, 113, 82, 98, 139, 179, 113]
# ======================================================================
# ========= Episode 999 ================================================
# Total steps: 133343
# Episode rewards, last 10: [-251.64904525248747, -198.55706620874184, -141.35293967083453, -319.7296975963659, -213.43737598307206, -314.42112388940188, -282.36340339878268, -408.51427331169401, -143.30009627125213, -226.1452385644146]
# Mean over last 125 episodes: -227.385534484
# Episode lengths, last 10: [88, 119, 81, 101, 141, 90, 81, 102, 63, 92]
# ======================================================================
# ========= Episode 1124 ================================================
# Total steps: 145011
# Episode rewards, last 10: [-190.11354182006585, -310.75790811138143, -106.09586248063133, -91.797005305946229, -166.72891510641, -154.82357243777739, -149.70362032449214, -107.62965898256691, -403.31819757212173, -206.92730822859346]
# Mean over last 125 episodes: -225.298087685
# Episode lengths, last 10: [80, 107, 73, 63, 91, 126, 123, 92, 126, 94]
# =======================================================================
# ========= Episode 1249 ================================================
# Total steps: 156933
# Episode rewards, last 10: [-617.40482909910361, -236.73695677785253, -248.2313988171741, -251.2467904819413, -169.36961497832743, -348.48062924156488, -277.52737766450673, -239.34880397690426, -179.42293281523189, -98.819432522679662]
# Mean over last 125 episodes: -232.222579865
# Episode lengths, last 10: [109, 70, 106, 96, 97, 94, 70, 75, 89, 66]
# =======================================================================

# %%
def plot_results(ddql_res, window = 100, std_coef = 0.2, results_over = 1000):
    res_lists = [k.rList for k in ddql_res]
    res_lists = np.array(res_lists)
    pd.DataFrame(data = res_lists)
    mean = res_lists.mean(axis = 0)
    std = res_lists.std(axis = 0)
    rol_mean = np.nan_to_num(pd.Series(mean).rolling(window = window).mean())[window:]
    rol_std = np.nan_to_num(pd.Series(std).rolling(window = window).mean())[window:]
    plt.figure()
    index = np.arange(window, len(rol_mean) + window)
    plt.plot(index, rol_mean)
    plt.fill_between(index, rol_mean-std_coef*rol_std, rol_mean+std_coef*rol_std, color='b', alpha=0.1)
    return max(rol_mean[window:results_over]), rol_mean[window:results_over].mean(), pd.DataFrame(data = res_lists)

# %%
greedy_max, greedy_auc, greedy_df = plot_results(res, 100, 0.2)
plt.savefig("egreedy_ll.png")

# %%
boltzman_max, boltzman_auc, boltzman_df = plot_results(res_b, 100, 0.2)
plt.savefig("boltzman_ll.png")

# %%
print greedy_max, greedy_auc
print boltzman_max, boltzman_auc
# Out:
# -178.062752422 -185.322842313
# -181.08771765 -191.779724395

# %%
greedy_df.to_csv("greedy.csv")

# %%
boltzman_df.to_csv("boltzman.csv")
